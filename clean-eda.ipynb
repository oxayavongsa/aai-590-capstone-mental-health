# %% [markdown]
# # Final Project - Mental Risk prediction

# %% [markdown]
# ### Cleaning and Inspecting Original Data

# %%
import pandas as pd

# %%
file_path = "./data-assets/Mental Health Dataset.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 0             Yes                      No     Not sure
# 1             Yes                      No           No
# 2             Yes                      No          Yes
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes

# %%
print("\nShape: ", df.shape)
print("\nColumns: ", df.columns.tolist())
print("\nData Types:\n", df.dtypes)
# Out:
# Shape:  (292364, 17)
#
# Columns:  ['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed', 'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress', 'Changes_Habits', 'Mental_Health_History', 'Mood_Swings', 'Coping_Struggles', 'Work_Interest', 'Social_Weakness', 'mental_health_interview', 'care_options']
#
# Data Types:
#  Timestamp                  object
# Gender                     object
# Country                    object
# Occupation                 object
# self_employed              object
# family_history             object
# treatment                  object
# Days_Indoors               object
# Growing_Stress             object
# Changes_Habits             object
# Mental_Health_History      object
# Mood_Swings                object
# Coping_Struggles           object
# Work_Interest              object
# Social_Weakness            object
# mental_health_interview    object
# care_options               object
# dtype: object

# %%
print("Missing values per column:")
print(df.isnull().sum())

print("\nDuplicates:", df.duplicated().sum())
# Out:
# Missing values per column:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# care_options                  0
# dtype: int64
#
# Duplicates: 2313

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# All columns except Timestamp to category
cat_cols = [col for col in df.columns if col != 'Timestamp']
df[cat_cols] = df[cat_cols].astype('category')

print("\nData Types after conversion:\n", df.dtypes)
# Out:
# Data Types after conversion:
#  Timestamp                  datetime64[ns]
# Gender                           category
# Country                          category
# Occupation                       category
# self_employed                    category
# family_history                   category
# treatment                        category
# Days_Indoors                     category
# Growing_Stress                   category
# Changes_Habits                   category
# Mental_Health_History            category
# Mood_Swings                      category
# Coping_Struggles                 category
# Work_Interest                    category
# Social_Weakness                  category
# mental_health_interview          category
# care_options                     category
# dtype: object

# %%
# #  Clean Categorial Values

# import numpy as np

# # Standardize yes/no-like responses across all columns
# def standardize_binary(val):
#     if isinstance(val, str):
#         val_lower = val.strip().lower()
#         if val_lower in ['yes', 'y']:
#             return 'Yes'
#         elif val_lower in ['no', 'n']:
#             return 'No'
#         elif val_lower in ['maybe', 'not sure', 'not_sure', 'unsure']: # not_sure, unsure is not in the dataset 
#             return 'Maybe'
#     return val

# # Apply standardization to object/category columns
# for col in df.select_dtypes(include=['object', 'category']).columns:
#     df[col] = df[col].apply(standardize_binary)

# # Preview cleaned categories
# for col in df.select_dtypes(include=['object', 'category']).columns:
#     print(f"\nColumn: {col}")
#     print(df[col].value_counts(dropna=False))
# Out:
# Column: Gender
# Gender
# Male      195996
# Female     52514
# Name: count, dtype: int64
#
# Column: Country
# Country
# United States             146490
# United Kingdom             43273
# Canada                     16022
# Australia                   5243
# Netherlands                 4894
# Ireland                     4694
# Germany                     3825
# Sweden                      2461
# India                       2344
# France                      1913
# Brazil                      1912
# New Zealand                 1710
# South Africa                1708
# Italy                       1276
# Switzerland                 1275
# Israel                      1274
# Belgium                      753
# Poland                       752
# Russia                       638
# Denmark                      638
# Singapore                    638
# Greece                       636
# Bosnia and Herzegovina       319
# Finland                      319
# Costa Rica                   319
# Nigeria                      319
# Croatia                      319
# Thailand                     319
# Portugal                     319
# Colombia                     318
# Czech Republic               318
# Georgia                      318
# Philippines                  318
# Moldova                      318
# Mexico                       318
# Name: count, dtype: int64
#
# Column: Occupation
# Occupation
# Housewife    58356
# Corporate    53849
# Student      48879
# Others       45272
# Business     42154
# Name: count, dtype: int64
#
# Column: self_employed
# self_employed
# No     219626
# Yes     24392
# NaN      4492
# Name: count, dtype: int64
#
# Column: family_history
# family_history
# No     148325
# Yes    100185
# Name: count, dtype: int64
#
# Column: treatment
# treatment
# Yes    127270
# No     121240
# Name: count, dtype: int64
#
# Column: Days_Indoors
# Days_Indoors
# 1-14 days             52478
# 31-60 days            52095
# Go out Every day      49756
# More than 2 months    47306
# 15-30 days            46875
# Name: count, dtype: int64
#
# Column: Growing_Stress
# Growing_Stress
# Maybe    86881
# Yes      86738
# No       74891
# Name: count, dtype: int64
#
# Column: Changes_Habits
# Changes_Habits
# Yes      92303
# No       78261
# Maybe    77946
# Name: count, dtype: int64
#
# Column: Mental_Health_History
# Mental_Health_History
# Maybe    84923
# No       84338
# Yes      79249
# Name: count, dtype: int64
#
# Column: Mood_Swings
# Mood_Swings
# Medium    88149
# Low       85689
# High      74672
# Name: count, dtype: int64
#
# Column: Coping_Struggles
# Coping_Struggles
# No     130154
# Yes    118356
# Name: count, dtype: int64
#
# Column: Work_Interest
# Work_Interest
# No       89238
# Maybe    85810
# Yes      73462
# Name: count, dtype: int64
#
# Column: Social_Weakness
# Social_Weakness
# No       84449
# Yes      82997
# Maybe    81064
# Name: count, dtype: int64
#
# Column: mental_health_interview
# mental_health_interview
# No       198358
# Maybe     43023
# Yes        7128
# NaN           1
# Name: count, dtype: int64
#
# Column: care_options
# care_options
# No       99855
# Yes      82011
# Maybe    66643
# NaN          1
# Name: count, dtype: int64

# %%
# #  Clean and Convert Days_Indoors
# #  This script handles the Days_Indoors column and covert it into a numeric range suitable for ML models

# # Clean and convert 'Days_Indoors' to ordered categories or numeric range

# # Preview unique values
# print("\nUnique values in 'Days_Indoors' before cleaning:")
# print(df['Days_Indoors'].unique())

# # Create a mapping to convert ranges to mid-point numeric values
# # Fix mapping based on actual values
# days_indoors_map = {
#     '1-14 days': 7,
#     '15-30 days': 22,
#     '31-60 days': 45,
#     'Go out Every day': 0,
#     'More than 2 months': 90
# }

# # Apply mapping (fill unmapped values with NaN)
# df['Days_Indoors_Clean'] = df['Days_Indoors'].map(days_indoors_map)

# # Show result
# print("\nValue counts after mapping 'Days_Indoors':")
# print(df['Days_Indoors_Clean'].value_counts(dropna=False).sort_index())
# Out:
# Unique values in 'Days_Indoors' before cleaning:
# ['1-14 days', 'Go out Every day', 'More than 2 months', '15-30 days', '31-60 days']
# Categories (5, object): ['1-14 days', '15-30 days', '31-60 days', 'Go out Every day',
#                          'More than 2 months']
#
# Value counts after mapping 'Days_Indoors':
# Days_Indoors_Clean
# 7     52478
# 22    46875
# 45    52095
# 0     49756
# 90    47306
# Name: count, dtype: int64

# %%
# # Extract features from Timestamp

# # Ensure Timestamp is datetime
# df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# # Extract useful time features
# df['Year'] = df['Timestamp'].dt.year
# df['Month'] = df['Timestamp'].dt.month
# df['Weekday'] = df['Timestamp'].dt.day_name()

# # Preview extracted columns
# print("\nTimestamp feature preview:")
# print(df[['Timestamp', 'Year', 'Month', 'Weekday']].head())

# # Optional: drop Timestamp if not needed further
# # df.drop(columns=['Timestamp'], inplace=True)
# Out:
# Timestamp feature preview:
#             Timestamp  Year  Month    Weekday
# 0 2014-08-27 11:29:00  2014      8  Wednesday
# 1 2014-08-27 11:31:00  2014      8  Wednesday
# 2 2014-08-27 11:32:00  2014      8  Wednesday
# 3 2014-08-27 11:37:00  2014      8  Wednesday
# 4 2014-08-27 11:43:00  2014      8  Wednesday

# %%
# #  Handle Missing Values Gracefully
# #  Code block to replace the harsh dropna() approach with smarter handling:

# # Handle missing values more gracefully

# # Check missing value counts
# print("\nMissing values per column BEFORE handling:")
# print(df.isnull().sum())

# # Strategy 1: Fill 'Maybe' with separate category where appropriate
# # Already handled in earlier standardization step

# # Strategy 2: For 'Days_Indoors_Clean', fill NaN with median (or mean)
# df['Days_Indoors_Clean'] = pd.to_numeric(df['Days_Indoors_Clean'], errors='coerce')
# df['Days_Indoors_Clean'] = df['Days_Indoors_Clean'].fillna(df['Days_Indoors_Clean'].median())

# # Strategy 3: Drop rows with missing 'treatment' (target variable)
# df = df[df['treatment'].notnull()]

# # Strategy 4: For other remaining NaNs, fill with 'Unknown' or most frequent value
# for col in df.columns:
#     if df[col].dtype.name == 'category' or df[col].dtype == object:
#         most_frequent = df[col].mode().iloc[0]
#         df[col] = df[col].fillna(most_frequent)

# # Strategy 5: Final check on missing values
# print("\nMissing values per column AFTER handling:")
# print(df.isnull().sum())
# Out:
# Missing values per column BEFORE handling:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# Days_Indoors_Clean         0
# Year                       0
# Weekday                    0
# Month                      0
# dtype: int64
#
# Missing values per column AFTER handling:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# Days_Indoors_Clean         0
# Year                       0
# Weekday                    0
# Month                      0
# dtype: int64

# %%
# Remove duplicates
df = df.drop_duplicates()

# Remove NaN values
df = df.dropna()

print("\n Shape after cleaning: ", df.shape)
print("\nMissing values after cleaning:")
print(df.isnull().sum())
# Out:
#  Shape after cleaning:  (284858, 17)
#
# Missing values after cleaning:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                             Timestamp  Gender        Country Occupation  \
# count                          284858  284858         284858     284858
# unique                            NaN       2             35          5
# top                               NaN    Male  United States  Housewife
# freq                              NaN  234000         165869      64728
# mean    2014-09-09 11:47:30.245174784     NaN            NaN        NaN
# min               2014-08-27 11:35:00     NaN            NaN        NaN
# 25%               2014-08-27 14:28:00     NaN            NaN        NaN
# 50%               2014-08-28 03:06:00     NaN            NaN        NaN
# 75%               2014-08-28 23:03:00     NaN            NaN        NaN
# max               2016-02-01 23:04:00     NaN            NaN        NaN
#
#        self_employed family_history treatment Days_Indoors Growing_Stress  \
# count         284858         284858    284858       284858         284858
# unique             2              2         2            5              3
# top               No             No       Yes    1-14 days          Maybe
# freq          255711         172357    143331        61994          97540
# mean             NaN            NaN       NaN          NaN            NaN
# min              NaN            NaN       NaN          NaN            NaN
# 25%              NaN            NaN       NaN          NaN            NaN
# 50%              NaN            NaN       NaN          NaN            NaN
# 75%              NaN            NaN       NaN          NaN            NaN
# max              NaN            NaN       NaN          NaN            NaN
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# count          284858                284858      284858           284858
# unique              3                     3           3                2
# top               Yes                    No      Medium               No
# freq           106844                101474       98592           150318
# mean              NaN                   NaN         NaN              NaN
# min               NaN                   NaN         NaN              NaN
# 25%               NaN                   NaN         NaN              NaN
# 50%               NaN                   NaN         NaN              NaN
# 75%               NaN                   NaN         NaN              NaN
# max               NaN                   NaN         NaN              NaN
#
#        Work_Interest Social_Weakness mental_health_interview care_options
# count         284858          284858                  284858       284858
# unique             3               3                       3            3
# top               No           Maybe                      No           No
# freq          103136          100746                  227036       115233
# mean             NaN             NaN                     NaN          NaN
# min              NaN             NaN                     NaN          NaN
# 25%              NaN             NaN                     NaN          NaN
# 50%              NaN             NaN                     NaN          NaN
# 75%              NaN             NaN                     NaN          NaN
# max              NaN             NaN                     NaN          NaN

# %%
# Print the df to verify all cleaning steps
print("\nCleaned DataFrame:")
df.head()
# Out:
# Cleaned DataFrame:
#             Timestamp  Gender        Country Occupation self_employed  \
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
# 5 2014-08-27 11:49:00  Female         Poland  Corporate            No
# 6 2014-08-27 11:51:00  Female      Australia  Corporate            No
# 7 2014-08-27 11:52:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
# 5             No       Yes    1-14 days            Yes             No
# 6            Yes       Yes    1-14 days            Yes             No
# 7             No        No    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
# 5                   Yes      Medium               No            No
# 6                   Yes      Medium               No            No
# 7                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes
# 5             Yes                   Maybe     Not sure
# 6             Yes                      No     Not sure
# 7             Yes                      No           No

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2_contingency
import seaborn as sns

# %%
for col in cat_cols:
    print(f"\n=== {col} ===")
    plt.figure(figsize=(16, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    if col.lower() == "country":
        plt.xticks(rotation=90)
    else:
        plt.xticks(rotation=45)
    plt.show()
# Out:
# === Gender ===
# === Country ===
# === Occupation ===
# === self_employed ===
# === family_history ===
# === treatment ===
# === Days_Indoors ===
# === Growing_Stress ===
# === Changes_Habits ===
# === Mental_Health_History ===
# === Mood_Swings ===
# === Coping_Struggles ===
# === Work_Interest ===
# === Social_Weakness ===
# === mental_health_interview ===
# === care_options ===

# %%
# Extract month (year and month)
df['Month'] = df['Timestamp'].dt.to_period('M')

monthly_counts = df['Month'].value_counts().sort_index()

plt.figure(figsize=(8,4))
monthly_counts.plot(kind='bar')
plt.title('Survey Responses Per Month')
plt.xlabel('Month')
plt.ylabel('Number of Responses')
plt.tight_layout()
plt.show()

# drop the 'Month' column
df.drop(columns=['Month'], inplace=True)

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2, p, dof, expected = chi2_contingency(confusion_matrix, correction=False)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))


cat_cols = [col for col in df.columns if str(df[col].dtype) == 'category']

# Initialize an empty DataFrame for the association matrix
assoc_matrix = pd.DataFrame(np.ones((len(cat_cols), len(cat_cols))),
                            index=cat_cols, columns=cat_cols)

for col1 in cat_cols:
    for col2 in cat_cols:
        if col1 == col2:
            assoc_matrix.loc[col1, col2] = 1.0
        else:
            assoc_matrix.loc[col1, col2] = cramers_v(df[col1], df[col2])

# %%
plt.figure(figsize=(12,10))
sns.heatmap(assoc_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True,
            cbar_kws={'label': "Cramér's V (Association Strength)"})
plt.title("Association Heatmap (Cramér's V) for Categorical Features")
plt.tight_layout()
plt.show()

# %%
# 1. Country vs. self_employed
ctab1 = pd.crosstab(df['Country'], df['self_employed'])
print("\nCountry vs. self_employed:\n", ctab1)
ctab1.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. self_employed')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 2. Occupation vs. self_employed
ctab2 = pd.crosstab(df['Occupation'], df['self_employed'])
print("\nOccupation vs. self_employed:\n", ctab2)
ctab2.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Occupation vs. self_employed')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# 3. Country vs. Gender (optional)
ctab3 = pd.crosstab(df['Country'], df['Gender'])
print("\nCountry vs. Gender:\n", ctab3)
ctab3.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. Gender')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 4. Country vs. family_history (optional)
ctab4 = pd.crosstab(df['Country'], df['family_history'])
print("\nCountry vs. family_history:\n", ctab4)
ctab4.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. family_history')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Country vs. self_employed:
#  self_employed               No   Yes
# Country
# Australia                 5234   780
# Belgium                    821     0
# Bosnia and Herzegovina     390     0
# Brazil                    1560   780
# Canada                   14676  2853
# Colombia                   390     0
# Costa Rica                 390     0
# Croatia                      0   390
# Czech Republic             390     0
# Denmark                      0   780
# Finland                    390     0
# France                    1950   390
# Georgia                    390     0
# Germany                   3510  1170
# Greece                     780     0
# India                     2381   390
# Ireland                   3592  1950
# Israel                    1560     0
# Italy                     1560     0
# Mexico                       0   390
# Moldova                    390     0
# Netherlands               4721  1170
# New Zealand               1991     0
# Nigeria                    390     0
# Philippines                390     0
# Poland                     431   390
# Portugal                   390     0
# Russia                     780     0
# Singapore                  780     0
# South Africa              1560   431
# Sweden                    2812     0
# Switzerland               1170   390
# Thailand                     0   390
# United Kingdom           43515  7061
# United States           156427  9442
# Occupation vs. self_employed:
#  self_employed     No   Yes
# Occupation
# Business       43947  4975
# Corporate      53408  6206
# Housewife      58093  6635
# Others         46212  5218
# Student        54051  6113
# Country vs. Gender:
#  Gender                  Female    Male
# Country
# Australia                 1724    4290
# Belgium                    431     390
# Bosnia and Herzegovina       0     390
# Brazil                       0    2340
# Canada                    3879   13650
# Colombia                     0     390
# Costa Rica                   0     390
# Croatia                      0     390
# Czech Republic               0     390
# Denmark                      0     780
# Finland                      0     390
# France                       0    2340
# Georgia                      0     390
# Germany                      0    4680
# Greece                       0     780
# India                      431    2340
# Ireland                    862    4680
# Israel                       0    1560
# Italy                        0    1560
# Mexico                       0     390
# Moldova                      0     390
# Netherlands                431    5460
# New Zealand                431    1560
# Nigeria                      0     390
# Philippines                  0     390
# Poland                     431     390
# Portugal                     0     390
# Russia                       0     780
# Singapore                    0     780
# South Africa               431    1560
# Sweden                     862    1950
# Switzerland                  0    1560
# Thailand                     0     390
# United Kingdom            6896   43680
# United States            34049  131820
# Country vs. family_history:
#  family_history             No    Yes
# Country
# Australia                3120   2894
# Belgium                   821      0
# Bosnia and Herzegovina      0    390
# Brazil                   1560    780
# Canada                   9832   7697
# Colombia                  390      0
# Costa Rica                390      0
# Croatia                   390      0
# Czech Republic              0    390
# Denmark                     0    780
# Finland                   390      0
# France                   1560    780
# Georgia                   390      0
# Germany                  3120   1560
# Greece                    780      0
# India                    2340    431
# Ireland                  3161   2381
# Israel                   1560      0
# Italy                    1560      0
# Mexico                    390      0
# Moldova                   390      0
# Netherlands              3551   2340
# New Zealand              1170    821
# Nigeria                   390      0
# Philippines               390      0
# Poland                    821      0
# Portugal                  390      0
# Russia                    780      0
# Singapore                 780      0
# South Africa              780   1211
# Sweden                   1950    862
# Switzerland               390   1170
# Thailand                  390      0
# United Kingdom          35818  14758
# United States           92613  73256

# %% [markdown]
# ### Defining Risk

# %%
# !pip install kmodes
from kmodes.kmodes import KModes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from kmodes) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from kmodes) (1.1.3)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from kmodes) (1.12.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from kmodes) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\envs\tensorflow\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)
# Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2

# %%
# Use only categorical feature columns (drop Timestamp if included)
cat_cols = [col for col in df.columns if str(df[col].dtype) == 'category']
X = df[cat_cols]

km = KModes(n_clusters=3, init='Huang', n_init=5, verbose=1, random_state=42)
clusters = km.fit_predict(X)

# Assign clusters to your DataFrame
df['risk_cluster'] = clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 77042, cost: 2021287.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 83429, cost: 1976895.0
# Run 2, iteration: 2/100, moves: 5905, cost: 1976895.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 61163, cost: 1957771.0
# Run 3, iteration: 2/100, moves: 10023, cost: 1957771.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 52994, cost: 2042047.0
# Run 4, iteration: 2/100, moves: 25554, cost: 2042047.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 99080, cost: 1978890.0
# Run 5, iteration: 2/100, moves: 583, cost: 1978890.0
# Best run was number 3

# %%
# Cluster centroids as a DataFrame
cluster_modes = pd.DataFrame(km.cluster_centroids_, columns=cat_cols)
print("Cluster modes:")
print(cluster_modes)

# Optionally, get value counts per cluster
df['risk_cluster'].value_counts()
# Out:
# Cluster modes:
#   Gender        Country Occupation self_employed family_history treatment  \
# 0   Male  United States    Student            No             No        No
# 1   Male  United States  Housewife            No             No        No
# 2   Male  United States  Housewife            No            Yes       Yes
#
#          Days_Indoors Growing_Stress Changes_Habits Mental_Health_History  \
# 0          31-60 days             No          Maybe                   Yes
# 1           1-14 days            Yes          Maybe                    No
# 2  More than 2 months          Maybe            Yes                 Maybe
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness  \
# 0         Low              Yes           Yes           Maybe
# 1         Low               No            No             Yes
# 2      Medium               No            No              No
#
#   mental_health_interview care_options
# 0                      No     Not sure
# 1                      No           No
# 2                      No          Yes
# risk_cluster
# 0    108400
# 1     90238
# 2     86220
# Name: count, dtype: int64

# %%
risk_labels = {
    2: "High",    # assign based on your inspection
    1: "Medium",
    0: "Low"
}
df['risk_label'] = df['risk_cluster'].map(risk_labels)

# %%
pd.set_option('display.max_rows', 100)  # Show up to 100 rows in the output
df.sample(n=100, random_state=42)  # 100 random rows, same each time with the seed
# Out:
#                  Timestamp  Gender         Country Occupation self_employed  \
# 227657 2014-08-29 07:12:00    Male   United States   Business            No
# 94904  2014-09-04 06:23:00    Male  United Kingdom  Corporate            No
# 250201 2014-08-27 19:28:00    Male   United States    Student            No
# 90823  2014-08-27 14:41:00    Male  United Kingdom     Others            No
# 215307 2014-08-28 17:27:00    Male   United States     Others            No
# 287457 2014-08-27 11:36:00    Male   United States    Student            No
# 128784 2014-08-27 11:35:00    Male          France    Student           Yes
# 145247 2014-08-29 07:12:00    Male   United States    Student            No
# 109351 2014-08-27 17:15:00    Male   United States  Corporate            No
# 29985  2014-08-29 11:23:00  Female          Canada    Student            No
# 23084  2014-08-29 09:53:00  Female   United States   Business            No
# 181446 2014-08-28 13:34:00    Male     Switzerland    Student            No
# 36276  2014-08-29 11:11:00  Female   United States  Corporate            No
# 177755 2014-08-28 13:32:00    Male          Brazil    Student            No
# 248368 2014-08-27 21:45:00    Male       Singapore     Others            No
# 1729   2014-08-27 15:29:00  Female   United States   Business            No
# 215111 2014-08-27 16:13:00    Male   United States     Others            No
# 189702 2014-08-27 12:01:00    Male   United States  Corporate            No
# 145292 2014-08-29 12:45:00    Male   United States    Student            No
# 186291 2014-08-28 05:12:00    Male  United Kingdom  Housewife            No
# 157292 2014-08-27 15:55:00    Male   United States  Corporate            No
# 99201  2014-09-01 09:15:00    Male          Sweden    Student            No
# 54108  2014-08-28 10:51:00    Male  United Kingdom  Housewife            No
# 46346  2014-08-27 11:37:00  Female   United States     Others            No
# 144923 2014-08-27 14:23:00    Male          Canada    Student            No
# 198018 2014-08-28 10:51:00    Male  United Kingdom  Housewife            No
# 123748 2014-08-29 10:33:00    Male   United States  Corporate            No
# 181957 2014-08-27 22:21:00    Male   United States   Business            No
# 222527 2014-08-27 19:34:00    Male          Canada  Housewife            No
# 47467  2014-08-27 15:29:00  Female   United States     Others            No
# 23484  2014-08-27 12:39:00  Female   United States    Student            No
# 191416 2014-08-29 12:27:00    Male   United States  Housewife            No
# 158891 2015-02-21 10:00:00    Male   United States     Others            No
# 238961 2014-08-27 12:54:00    Male   United States    Student            No
# 142837 2014-08-29 14:31:00    Male   United States  Housewife           Yes
# 256272 2014-08-27 15:15:00    Male  United Kingdom     Others            No
# 28551  2015-02-21 05:11:00  Female   United States  Corporate            No
# 19174  2014-08-27 20:48:00  Female   United States    Student            No
# 32919  2014-08-27 11:52:00  Female   United States   Business            No
# 154648 2014-08-27 12:02:00    Male  United Kingdom     Others            No
# 244613 2014-08-27 15:40:00    Male       Australia   Business            No
# 85739  2014-08-27 11:39:00    Male  United Kingdom  Corporate            No
# 171184 2015-02-21 06:19:00    Male  United Kingdom  Corporate            No
# 50314  2014-08-29 11:33:00  Female   United States  Housewife            No
# 254889 2014-08-27 11:57:00    Male   United States     Others            No
# 98062  2014-08-27 11:56:00    Male   United States  Housewife            No
# 286090 2014-08-29 09:01:00    Male          Canada   Business            No
# 247255 2014-08-28 14:00:00    Male   United States    Student            No
# 112856 2014-08-27 12:34:00    Male  United Kingdom   Business            No
# 54503  2014-08-27 13:56:00    Male   United States     Others            No
# 284205 2014-08-28 19:03:00    Male  United Kingdom    Student            No
# 36957  2014-08-27 18:02:00  Female   United States  Housewife            No
# 280327 2014-08-27 17:47:00    Male          Canada   Business            No
# 14353  2014-08-28 12:12:00  Female  United Kingdom    Student            No
# 68155  2014-08-27 18:18:00    Male   United States    Student            No
# 122781 2014-08-27 14:22:00    Male   United States    Student            No
# 46956  2014-08-27 12:18:00  Female   United States   Business            No
# 209661 2014-08-28 05:12:00    Male  United Kingdom  Corporate            No
# 40838  2014-08-28 01:56:00  Female   United States  Corporate            No
# 241451 2014-08-27 13:44:00    Male   United States  Housewife            No
# 186597 2014-08-27 11:36:00    Male   United States   Business            No
# 3841   2014-08-29 09:02:00  Female  United Kingdom    Student            No
# 164051 2014-08-27 15:43:00    Male   United States  Corporate            No
# 204119 2014-08-28 03:15:00    Male         Germany  Corporate            No
# 218796 2014-08-27 16:00:00    Male  United Kingdom  Housewife            No
# 261364 2014-08-28 10:52:00    Male   United States     Others            No
# 281387 2014-08-27 12:48:00    Male  United Kingdom     Others            No
# 258552 2014-08-27 11:36:00    Male   United States   Business            No
# 109425 2014-08-28 08:23:00    Male           India  Corporate            No
# 229609 2015-02-21 06:19:00    Male  United Kingdom  Housewife            No
# 149777 2014-08-27 12:48:00    Male  United Kingdom  Corporate            No
# 44710  2014-08-28 01:56:00  Female   United States   Business            No
# 42063  2014-08-28 13:08:00  Female   United States   Business            No
# 177575 2014-08-27 15:36:00    Male          Canada    Student           Yes
# 134792 2014-08-29 07:12:00    Male   United States    Student            No
# 226388 2014-08-28 17:59:00    Male  United Kingdom  Corporate           Yes
# 261882 2014-08-27 19:13:00    Male     Netherlands   Business            No
# 273388 2014-08-27 12:43:00    Male   United States  Corporate            No
# 277450 2014-08-28 22:17:00    Male   United States  Housewife            No
# 260460 2014-08-27 12:36:00    Male          Canada     Others            No
# 189870 2014-08-27 15:31:00    Male         Finland  Corporate            No
# 256541 2014-08-28 22:18:00    Male   United States     Others            No
# 225201 2014-08-29 08:26:00    Male         Germany  Housewife            No
# 19810  2014-08-28 21:41:00  Female   United States  Housewife            No
# 176637 2014-08-29 10:30:00    Male   United States  Corporate            No
# 139341 2014-08-27 13:12:00    Male  United Kingdom  Corporate            No
# 103426 2014-08-29 06:37:00    Male  United Kingdom   Business            No
# 193217 2014-08-29 07:12:00    Male   United States     Others            No
# 156549 2014-08-27 12:53:00    Male   United States   Business            No
# 83351  2014-08-27 12:42:00    Male   United States    Student            No
# 94921  2015-02-21 05:34:00    Male          Brazil  Corporate           Yes
# 20996  2014-08-28 03:29:00  Female       Australia  Housewife            No
# 77579  2014-08-28 22:23:00    Male     Netherlands  Housewife            No
# 206111 2014-08-28 22:18:00    Male   United States  Corporate            No
# 116021 2014-08-27 14:26:00    Male   United States  Housewife            No
# 62246  2014-08-29 10:13:00    Male   United States  Corporate            No
# 190272 2015-09-26 01:07:00    Male   United States  Corporate            No
# 274713 2014-08-27 14:51:00    Male  United Kingdom  Housewife            No
# 156971 2014-08-29 11:40:00    Male   United States   Business            No
# 90766  2014-08-27 13:27:00    Male          Canada     Others            No
#
#        family_history treatment        Days_Indoors Growing_Stress  \
# 227657             No        No           1-14 days            Yes
# 94904              No        No          15-30 days            Yes
# 250201             No       Yes          31-60 days            Yes
# 90823              No        No          31-60 days          Maybe
# 215307            Yes       Yes          15-30 days             No
# 287457             No       Yes          31-60 days          Maybe
# 128784            Yes        No          15-30 days             No
# 145247             No        No           1-14 days          Maybe
# 109351             No        No           1-14 days            Yes
# 29985             Yes       Yes    Go out Every day             No
# 23084             Yes        No    Go out Every day            Yes
# 181446            Yes        No           1-14 days          Maybe
# 36276              No        No  More than 2 months          Maybe
# 177755             No        No  More than 2 months            Yes
# 248368             No        No          15-30 days          Maybe
# 1729              Yes       Yes  More than 2 months          Maybe
# 215111             No        No          15-30 days             No
# 189702            Yes        No           1-14 days          Maybe
# 145292             No        No           1-14 days          Maybe
# 186291             No        No    Go out Every day          Maybe
# 157292             No        No    Go out Every day            Yes
# 99201              No        No          31-60 days          Maybe
# 54108              No        No  More than 2 months             No
# 46346             Yes       Yes  More than 2 months            Yes
# 144923             No       Yes           1-14 days          Maybe
# 198018             No        No           1-14 days            Yes
# 123748             No        No           1-14 days          Maybe
# 181957             No        No          15-30 days             No
# 222527             No        No          31-60 days             No
# 47467             Yes       Yes          31-60 days            Yes
# 23484             Yes        No    Go out Every day          Maybe
# 191416             No        No  More than 2 months            Yes
# 158891            Yes       Yes          15-30 days             No
# 238961             No       Yes           1-14 days          Maybe
# 142837            Yes       Yes          15-30 days            Yes
# 256272             No       Yes           1-14 days          Maybe
# 28551              No       Yes           1-14 days             No
# 19174             Yes       Yes  More than 2 months            Yes
# 32919              No        No          31-60 days            Yes
# 154648             No        No          15-30 days            Yes
# 244613             No        No          31-60 days             No
# 85739              No        No  More than 2 months            Yes
# 171184            Yes        No          15-30 days            Yes
# 50314             Yes        No    Go out Every day             No
# 254889             No        No           1-14 days             No
# 98062              No        No    Go out Every day            Yes
# 286090             No        No          15-30 days            Yes
# 247255            Yes        No    Go out Every day            Yes
# 112856            Yes        No          31-60 days          Maybe
# 54503              No        No    Go out Every day            Yes
# 284205             No       Yes           1-14 days             No
# 36957             Yes       Yes          15-30 days            Yes
# 280327             No        No  More than 2 months            Yes
# 14353              No        No          31-60 days            Yes
# 68155             Yes       Yes          31-60 days          Maybe
# 122781             No        No          31-60 days          Maybe
# 46956              No        No           1-14 days            Yes
# 209661             No        No  More than 2 months             No
# 40838             Yes       Yes           1-14 days             No
# 241451             No        No           1-14 days             No
# 186597             No       Yes          31-60 days             No
# 3841              Yes        No          15-30 days          Maybe
# 164051             No        No           1-14 days             No
# 204119             No        No    Go out Every day          Maybe
# 218796             No        No    Go out Every day          Maybe
# 261364            Yes       Yes    Go out Every day             No
# 281387             No       Yes    Go out Every day            Yes
# 258552             No       Yes          31-60 days            Yes
# 109425             No        No           1-14 days            Yes
# 229609            Yes        No           1-14 days             No
# 149777             No       Yes           1-14 days            Yes
# 44710             Yes       Yes          15-30 days          Maybe
# 42063              No       Yes    Go out Every day          Maybe
# 177575             No        No  More than 2 months            Yes
# 134792             No        No  More than 2 months             No
# 226388             No        No  More than 2 months             No
# 261882            Yes       Yes    Go out Every day            Yes
# 273388            Yes       Yes  More than 2 months          Maybe
# 277450            Yes       Yes    Go out Every day             No
# 260460             No       Yes           1-14 days             No
# 189870             No        No           1-14 days          Maybe
# 256541            Yes       Yes           1-14 days          Maybe
# 225201             No        No    Go out Every day          Maybe
# 19810             Yes       Yes  More than 2 months          Maybe
# 176637             No        No           1-14 days            Yes
# 139341             No        No           1-14 days             No
# 103426            Yes        No    Go out Every day          Maybe
# 193217             No        No           1-14 days          Maybe
# 156549            Yes       Yes          15-30 days            Yes
# 83351             Yes       Yes           1-14 days            Yes
# 94921              No       Yes          15-30 days            Yes
# 20996             Yes       Yes    Go out Every day             No
# 77579             Yes       Yes           1-14 days             No
# 206111            Yes       Yes          15-30 days             No
# 116021            Yes        No           1-14 days             No
# 62246             Yes        No          15-30 days            Yes
# 190272            Yes       Yes           1-14 days          Maybe
# 274713             No        No          15-30 days          Maybe
# 156971            Yes       Yes          15-30 days            Yes
# 90766             Yes       Yes          31-60 days          Maybe
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# 227657          Maybe                   Yes        High               No
# 94904             Yes                   Yes         Low              Yes
# 250201            Yes                   Yes      Medium               No
# 90823              No                    No      Medium              Yes
# 215307            Yes                   Yes         Low              Yes
# 287457            Yes                 Maybe        High              Yes
# 128784            Yes                 Maybe         Low               No
# 145247             No                 Maybe         Low              Yes
# 109351          Maybe                 Maybe         Low              Yes
# 29985             Yes                   Yes         Low               No
# 23084              No                 Maybe        High               No
# 181446             No                   Yes      Medium               No
# 36276             Yes                    No      Medium               No
# 177755          Maybe                   Yes      Medium              Yes
# 248368             No                   Yes        High               No
# 1729            Maybe                    No      Medium              Yes
# 215111            Yes                   Yes         Low              Yes
# 189702             No                    No         Low              Yes
# 145292             No                 Maybe         Low              Yes
# 186291            Yes                    No         Low               No
# 157292          Maybe                 Maybe         Low               No
# 99201             Yes                    No      Medium              Yes
# 54108             Yes                   Yes      Medium               No
# 46346           Maybe                 Maybe        High              Yes
# 144923             No                 Maybe         Low              Yes
# 198018            Yes                    No      Medium               No
# 123748            Yes                 Maybe         Low               No
# 181957          Maybe                    No        High               No
# 222527          Maybe                   Yes      Medium              Yes
# 47467             Yes                    No      Medium               No
# 23484             Yes                   Yes         Low               No
# 191416             No                    No         Low               No
# 158891            Yes                    No        High               No
# 238961            Yes                 Maybe      Medium               No
# 142837          Maybe                   Yes      Medium               No
# 256272          Maybe                   Yes      Medium               No
# 28551              No                   Yes        High              Yes
# 19174              No                 Maybe         Low               No
# 32919             Yes                 Maybe         Low              Yes
# 154648            Yes                   Yes        High              Yes
# 244613             No                    No         Low              Yes
# 85739           Maybe                    No        High               No
# 171184             No                 Maybe      Medium              Yes
# 50314              No                    No      Medium               No
# 254889            Yes                    No         Low               No
# 98062             Yes                   Yes      Medium               No
# 286090          Maybe                   Yes        High               No
# 247255            Yes                    No      Medium               No
# 112856          Maybe                 Maybe         Low               No
# 54503             Yes                    No      Medium              Yes
# 284205             No                    No         Low              Yes
# 36957              No                    No        High              Yes
# 280327            Yes                 Maybe      Medium               No
# 14353              No                 Maybe         Low               No
# 68155              No                   Yes         Low              Yes
# 122781             No                    No        High              Yes
# 46956             Yes                    No      Medium              Yes
# 209661             No                 Maybe        High              Yes
# 40838             Yes                   Yes        High              Yes
# 241451             No                    No         Low               No
# 186597            Yes                   Yes      Medium               No
# 3841              Yes                   Yes        High              Yes
# 164051            Yes                 Maybe         Low               No
# 204119             No                    No      Medium              Yes
# 218796             No                 Maybe         Low              Yes
# 261364            Yes                   Yes        High               No
# 281387            Yes                    No      Medium              Yes
# 258552          Maybe                   Yes         Low              Yes
# 109425          Maybe                 Maybe         Low              Yes
# 229609          Maybe                   Yes      Medium               No
# 149777          Maybe                   Yes         Low               No
# 44710             Yes                   Yes        High               No
# 42063             Yes                 Maybe         Low               No
# 177575          Maybe                   Yes      Medium              Yes
# 134792            Yes                   Yes        High               No
# 226388          Maybe                 Maybe      Medium               No
# 261882             No                    No        High              Yes
# 273388            Yes                    No         Low               No
# 277450          Maybe                    No        High               No
# 260460            Yes                    No      Medium              Yes
# 189870             No                    No         Low              Yes
# 256541          Maybe                   Yes      Medium               No
# 225201             No                    No        High              Yes
# 19810           Maybe                   Yes      Medium              Yes
# 176637          Maybe                    No         Low               No
# 139341          Maybe                   Yes      Medium               No
# 103426             No                   Yes         Low              Yes
# 193217            Yes                 Maybe         Low              Yes
# 156549            Yes                    No      Medium               No
# 83351             Yes                    No      Medium               No
# 94921             Yes                   Yes         Low              Yes
# 20996              No                    No        High               No
# 77579              No                 Maybe      Medium               No
# 206111            Yes                    No        High               No
# 116021            Yes                 Maybe      Medium              Yes
# 62246           Maybe                    No      Medium               No
# 190272             No                    No         Low              Yes
# 274713          Maybe                 Maybe         Low               No
# 156971            Yes                    No      Medium               No
# 90766              No                    No      Medium              Yes
#
#        Work_Interest Social_Weakness mental_health_interview care_options  \
# 227657           Yes             Yes                      No     Not sure
# 94904            Yes              No                      No           No
# 250201            No              No                      No     Not sure
# 90823          Maybe             Yes                      No           No
# 215307         Maybe             Yes                      No          Yes
# 287457           Yes           Maybe                      No           No
# 128784         Maybe             Yes                   Maybe           No
# 145247            No           Maybe                      No     Not sure
# 109351           Yes           Maybe                      No           No
# 29985             No             Yes                      No     Not sure
# 23084             No              No                      No     Not sure
# 181446           Yes           Maybe                      No           No
# 36276          Maybe           Maybe                      No     Not sure
# 177755            No           Maybe                   Maybe           No
# 248368           Yes           Maybe                      No           No
# 1729             Yes              No                      No     Not sure
# 215111         Maybe             Yes                      No           No
# 189702         Maybe             Yes                   Maybe          Yes
# 145292            No           Maybe                      No          Yes
# 186291           Yes           Maybe                   Maybe           No
# 157292           Yes           Maybe                   Maybe           No
# 99201             No             Yes                      No     Not sure
# 54108          Maybe           Maybe                      No           No
# 46346          Maybe             Yes                   Maybe          Yes
# 144923            No           Maybe                      No           No
# 198018            No             Yes                      No           No
# 123748            No             Yes                      No     Not sure
# 181957         Maybe             Yes                      No     Not sure
# 222527         Maybe              No                      No           No
# 47467            Yes           Maybe                      No     Not sure
# 23484            Yes             Yes                      No     Not sure
# 191416            No             Yes                      No          Yes
# 158891         Maybe              No                      No           No
# 238961            No              No                      No           No
# 142837         Maybe              No                      No     Not sure
# 256272            No           Maybe                      No     Not sure
# 28551            Yes             Yes                      No           No
# 19174             No             Yes                      No          Yes
# 32919          Maybe              No                      No           No
# 154648           Yes             Yes                   Maybe     Not sure
# 244613            No              No                      No     Not sure
# 85739          Maybe           Maybe                      No           No
# 171184            No             Yes                   Maybe     Not sure
# 50314             No           Maybe                      No           No
# 254889         Maybe              No                   Maybe          Yes
# 98062            Yes             Yes                      No     Not sure
# 286090            No              No                   Maybe     Not sure
# 247255         Maybe           Maybe                      No          Yes
# 112856         Maybe             Yes                      No           No
# 54503          Maybe           Maybe                      No          Yes
# 284205           Yes           Maybe                      No           No
# 36957          Maybe             Yes                      No          Yes
# 280327            No           Maybe                      No     Not sure
# 14353            Yes              No                   Maybe           No
# 68155          Maybe             Yes                      No           No
# 122781         Maybe           Maybe                      No     Not sure
# 46956            Yes             Yes                      No     Not sure
# 209661         Maybe             Yes                   Maybe           No
# 40838             No             Yes                      No          Yes
# 241451         Maybe             Yes                   Maybe           No
# 186597           Yes           Maybe                      No           No
# 3841              No              No                      No     Not sure
# 164051           Yes           Maybe                      No           No
# 204119           Yes              No                   Maybe          Yes
# 218796         Maybe              No                   Maybe           No
# 261364         Maybe           Maybe                      No           No
# 281387            No           Maybe                      No          Yes
# 258552           Yes             Yes                      No           No
# 109425           Yes           Maybe                   Maybe           No
# 229609         Maybe             Yes                   Maybe     Not sure
# 149777            No             Yes                      No          Yes
# 44710          Maybe           Maybe                      No          Yes
# 42063          Maybe           Maybe                      No           No
# 177575            No           Maybe                      No           No
# 134792         Maybe              No                      No     Not sure
# 226388         Maybe           Maybe                      No          Yes
# 261882            No              No                   Maybe     Not sure
# 273388           Yes           Maybe                      No     Not sure
# 277450           Yes           Maybe                      No     Not sure
# 260460         Maybe              No                   Maybe           No
# 189870         Maybe             Yes                      No           No
# 256541            No           Maybe                     Yes     Not sure
# 225201            No           Maybe                   Maybe     Not sure
# 19810             No              No                      No     Not sure
# 176637         Maybe              No                   Maybe     Not sure
# 139341           Yes           Maybe                     Yes           No
# 103426           Yes              No                      No           No
# 193217         Maybe           Maybe                      No     Not sure
# 156549            No              No                      No           No
# 83351          Maybe             Yes                      No           No
# 94921            Yes              No                      No          Yes
# 20996          Maybe             Yes                      No          Yes
# 77579            Yes              No                   Maybe           No
# 206111           Yes              No                     Yes     Not sure
# 116021         Maybe           Maybe                   Maybe           No
# 62246          Maybe           Maybe                      No           No
# 190272         Maybe             Yes                      No          Yes
# 274713            No           Maybe                      No           No
# 156971            No              No                      No          Yes
# 90766          Maybe             Yes                      No          Yes
#
#        risk_label  risk_cluster
# 227657     Medium             1
# 94904         Low             0
# 250201       High             2
# 90823      Medium             1
# 215307        Low             0
# 287457        Low             0
# 128784     Medium             1
# 145247        Low             0
# 109351        Low             0
# 29985         Low             0
# 23084        High             2
# 181446        Low             0
# 36276        High             2
# 177755        Low             0
# 248368        Low             0
# 1729         High             2
# 215111        Low             0
# 189702     Medium             1
# 145292        Low             0
# 186291     Medium             1
# 157292     Medium             1
# 99201         Low             0
# 54108         Low             0
# 46346        High             2
# 144923        Low             0
# 198018     Medium             1
# 123748     Medium             1
# 181957     Medium             1
# 222527        Low             0
# 47467        High             2
# 23484         Low             0
# 191416     Medium             1
# 158891       High             2
# 238961       High             2
# 142837       High             2
# 256272        Low             0
# 28551         Low             0
# 19174        High             2
# 32919         Low             0
# 154648        Low             0
# 244613        Low             0
# 85739      Medium             1
# 171184     Medium             1
# 50314      Medium             1
# 254889     Medium             1
# 98062      Medium             1
# 286090     Medium             1
# 247255       High             2
# 112856     Medium             1
# 54503         Low             0
# 284205        Low             0
# 36957      Medium             1
# 280327       High             2
# 14353         Low             0
# 68155         Low             0
# 122781        Low             0
# 46956      Medium             1
# 209661        Low             0
# 40838        High             2
# 241451     Medium             1
# 186597        Low             0
# 3841          Low             0
# 164051        Low             0
# 204119        Low             0
# 218796     Medium             1
# 261364       High             2
# 281387       High             2
# 258552        Low             0
# 109425        Low             0
# 229609     Medium             1
# 149777     Medium             1
# 44710        High             2
# 42063        High             2
# 177575        Low             0
# 134792        Low             0
# 226388        Low             0
# 261882       High             2
# 273388       High             2
# 277450        Low             0
# 260460     Medium             1
# 189870     Medium             1
# 256541       High             2
# 225201        Low             0
# 19810        High             2
# 176637     Medium             1
# 139341        Low             0
# 103426        Low             0
# 193217        Low             0
# 156549       High             2
# 83351      Medium             1
# 94921         Low             0
# 20996        High             2
# 77579        High             2
# 206111       High             2
# 116021       High             2
# 62246      Medium             1
# 190272     Medium             1
# 274713     Medium             1
# 156971       High             2
# 90766        High             2

# %%
pd.reset_option('display.max_rows')

# %%
sns.countplot(x='risk_label', data=df, order=["Low", "Medium", "High"])
plt.title("Distribution of Risk Labels")
plt.xlabel("Risk Level")
plt.ylabel("Number of Respondents")
plt.tight_layout()
plt.show()

# %%
df.drop(columns=['risk_cluster'], inplace=True)  # Drop the cluster column 
df.head()
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
# 5 2014-08-27 11:49:00  Female         Poland  Corporate            No
# 6 2014-08-27 11:51:00  Female      Australia  Corporate            No
# 7 2014-08-27 11:52:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
# 5             No       Yes    1-14 days            Yes             No
# 6            Yes       Yes    1-14 days            Yes             No
# 7             No        No    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
# 5                   Yes      Medium               No            No
# 6                   Yes      Medium               No            No
# 7                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options risk_label
# 3             Yes                   Maybe          Yes       High
# 4             Yes                      No          Yes       High
# 5             Yes                   Maybe     Not sure     Medium
# 6             Yes                      No     Not sure     Medium
# 7             Yes                      No           No     Medium

# %%
df['risk_label'] = df['risk_label'].astype('category')


cat_cols = [col for col in df.columns if str(df[col].dtype) == 'category']

assoc_matrix = pd.DataFrame(np.eye(len(cat_cols)), index=cat_cols, columns=cat_cols)
for i, col1 in enumerate(cat_cols):
    for j, col2 in enumerate(cat_cols):
        if i < j:
            v = cramers_v(df[col1], df[col2])
            assoc_matrix.loc[col1, col2] = v
            assoc_matrix.loc[col2, col1] = v

plt.figure(figsize=(12, 10))
sns.heatmap(
    assoc_matrix, 
    annot=True, 
    fmt=".2f", 
    cmap='coolwarm', 
    square=True,
    annot_kws={"size": 8},  
    cbar_kws={'label': "Cramér's V (Association Strength)"}
)
plt.title("Categorical Association Heatmap (Including risk_cluster)")
plt.xticks(fontsize=12, rotation=45, ha='right')
plt.yticks(fontsize=12, rotation=0)
plt.tight_layout()
plt.show()

# %%
# Saving the cleaned DataFrame
# Save cleaned dataset to CSV
df.to_csv("target_health_data.csv", index=False)
print("Cleaned data saved to 'cleaned_mental_health_data.csv'")
# Out:
# Cleaned data saved to 'cleaned_mental_health_data.csv'
