# %% [markdown]
# <a href="https://colab.research.google.com/github/oxayavongsa/aai-590-capstone-mental-health/blob/main/clean_filtered_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mental Health Risk Detection

# %% [markdown]
# ## Cleaning and Inspecting Original Data

# %%
import pandas as pd

# %%
df = pd.read_csv("aai-590-capstone-mental-health/data-assets/Mental Health Dataset.csv")
#df = pd.read_csv("./data-assets/Mental Health Dataset.csv")
df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 0             Yes                      No     Not sure
# 1             Yes                      No           No
# 2             Yes                      No          Yes
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes

# %%
print("\nShape: ", df.shape)
print("\nColumns:")
for col in df.columns:
    print(f" - {col}")

print("\nData Types:\n", df.dtypes)
# Out:
# Shape:  (292364, 17)
#
# Columns:
#  - Timestamp
#  - Gender
#  - Country
#  - Occupation
#  - self_employed
#  - family_history
#  - treatment
#  - Days_Indoors
#  - Growing_Stress
#  - Changes_Habits
#  - Mental_Health_History
#  - Mood_Swings
#  - Coping_Struggles
#  - Work_Interest
#  - Social_Weakness
#  - mental_health_interview
#  - care_options
#
# Data Types:
#  Timestamp                  object
# Gender                     object
# Country                    object
# Occupation                 object
# self_employed              object
# family_history             object
# treatment                  object
# Days_Indoors               object
# Growing_Stress             object
# Changes_Habits             object
# Mental_Health_History      object
# Mood_Swings                object
# Coping_Struggles           object
# Work_Interest              object
# Social_Weakness            object
# mental_health_interview    object
# care_options               object
# dtype: object

# %%
print("Missing values per column:")
print(df.isnull().sum())

print("\nDuplicates:", df.duplicated().sum())
# Out:
# Missing values per column:
# Timestamp                     0
# Gender                        0
# Country                       0
# Occupation                    0
# self_employed              5202
# family_history                0
# treatment                     0
# Days_Indoors                  0
# Growing_Stress                0
# Changes_Habits                0
# Mental_Health_History         0
# Mood_Swings                   0
# Coping_Struggles              0
# Work_Interest                 0
# Social_Weakness               0
# mental_health_interview       0
# care_options                  0
# dtype: int64
#
# Duplicates: 2313

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# All columns except Timestamp to category
cat_cols = [col for col in df.columns if col != 'Timestamp']
df[cat_cols] = df[cat_cols].astype('category')

print("\nData Types after conversion:\n", df.dtypes)
# Out:
# Data Types after conversion:
#  Timestamp                  datetime64[ns]
# Gender                           category
# Country                          category
# Occupation                       category
# self_employed                    category
# family_history                   category
# treatment                        category
# Days_Indoors                     category
# Growing_Stress                   category
# Changes_Habits                   category
# Mental_Health_History            category
# Mood_Swings                      category
# Coping_Struggles                 category
# Work_Interest                    category
# Social_Weakness                  category
# mental_health_interview          category
# care_options                     category
# dtype: object

# %%
# Remove duplicates
df = df.drop_duplicates()

# Remove NaN values
df = df.dropna()

print("\n Shape after cleaning: ", df.shape)
print("\nMissing values after cleaning:")
print(df.isnull().sum())
# Out:
#  Shape after cleaning:  (284858, 17)
#
# Missing values after cleaning:
# Timestamp                  0
# Gender                     0
# Country                    0
# Occupation                 0
# self_employed              0
# family_history             0
# treatment                  0
# Days_Indoors               0
# Growing_Stress             0
# Changes_Habits             0
# Mental_Health_History      0
# Mood_Swings                0
# Coping_Struggles           0
# Work_Interest              0
# Social_Weakness            0
# mental_health_interview    0
# care_options               0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                             Timestamp  Gender        Country Occupation  \
# count                          284858  284858         284858     284858
# unique                            NaN       2             35          5
# top                               NaN    Male  United States  Housewife
# freq                              NaN  234000         165869      64728
# mean    2014-09-09 11:47:30.245174784     NaN            NaN        NaN
# min               2014-08-27 11:35:00     NaN            NaN        NaN
# 25%               2014-08-27 14:28:00     NaN            NaN        NaN
# 50%               2014-08-28 03:06:00     NaN            NaN        NaN
# 75%               2014-08-28 23:03:00     NaN            NaN        NaN
# max               2016-02-01 23:04:00     NaN            NaN        NaN
#
#        self_employed family_history treatment Days_Indoors Growing_Stress  \
# count         284858         284858    284858       284858         284858
# unique             2              2         2            5              3
# top               No             No       Yes    1-14 days          Maybe
# freq          255711         172357    143331        61994          97540
# mean             NaN            NaN       NaN          NaN            NaN
# min              NaN            NaN       NaN          NaN            NaN
# 25%              NaN            NaN       NaN          NaN            NaN
# 50%              NaN            NaN       NaN          NaN            NaN
# 75%              NaN            NaN       NaN          NaN            NaN
# max              NaN            NaN       NaN          NaN            NaN
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# count          284858                284858      284858           284858
# unique              3                     3           3                2
# top               Yes                    No      Medium               No
# freq           106844                101474       98592           150318
# mean              NaN                   NaN         NaN              NaN
# min               NaN                   NaN         NaN              NaN
# 25%               NaN                   NaN         NaN              NaN
# 50%               NaN                   NaN         NaN              NaN
# 75%               NaN                   NaN         NaN              NaN
# max               NaN                   NaN         NaN              NaN
#
#        Work_Interest Social_Weakness mental_health_interview care_options
# count         284858          284858                  284858       284858
# unique             3               3                       3            3
# top               No           Maybe                      No           No
# freq          103136          100746                  227036       115233
# mean             NaN             NaN                     NaN          NaN
# min              NaN             NaN                     NaN          NaN
# 25%              NaN             NaN                     NaN          NaN
# 50%              NaN             NaN                     NaN          NaN
# 75%              NaN             NaN                     NaN          NaN
# max              NaN             NaN                     NaN          NaN

# %% [markdown]
# The dataset consists of 284,858 responses spanning from 2014 to 2016, with a strong male skew and a majority of participants from the United States. Most variables are categorical, with "Housewife" being the top occupation. Responses tend to be binary ("Yes"/"No"), suggesting a survey-based format. No true numerical variables are present for statistical summary beyond frequencies.

# %%
# Print the df to verify all cleaning steps
print("\nCleaned DataFrame:")
df.head()
# Out:
# Cleaned DataFrame:
#             Timestamp  Gender        Country Occupation self_employed  \
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
# 5 2014-08-27 11:49:00  Female         Poland  Corporate            No
# 6 2014-08-27 11:51:00  Female      Australia  Corporate            No
# 7 2014-08-27 11:52:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
# 5             No       Yes    1-14 days            Yes             No
# 6            Yes       Yes    1-14 days            Yes             No
# 7             No        No    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
# 5                   Yes      Medium               No            No
# 6                   Yes      Medium               No            No
# 7                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options
# 3             Yes                   Maybe          Yes
# 4             Yes                      No          Yes
# 5             Yes                   Maybe     Not sure
# 6             Yes                      No     Not sure
# 7             Yes                      No           No

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import chi2_contingency
import seaborn as sns

# %%
for col in cat_cols:
    print(f"\n=== {col} ===")
    plt.figure(figsize=(16, 4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    if col.lower() == "country":
        plt.xticks(rotation=90)
    else:
        plt.xticks(rotation=45)
    plt.show()
# Out:
# === Gender ===
# === Country ===
# === Occupation ===
# === self_employed ===
# === family_history ===
# === treatment ===
# === Days_Indoors ===
# === Growing_Stress ===
# === Changes_Habits ===
# === Mental_Health_History ===
# === Mood_Swings ===
# === Coping_Struggles ===
# === Work_Interest ===
# === Social_Weakness ===
# === mental_health_interview ===
# === care_options ===

# %%
# Extract month (year and month)
df['Month'] = df['Timestamp'].dt.to_period('M')

monthly_counts = df['Month'].value_counts().sort_index()

plt.figure(figsize=(8,4))
monthly_counts.plot(kind='bar')
plt.title('Survey Responses Per Month')
plt.xlabel('Month')
plt.ylabel('Number of Responses')
plt.tight_layout()
plt.show()

# drop the 'Month' column
df.drop(columns=['Month'], inplace=True)

# %% [markdown]
# **Cramer's V Heatmap**

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2, p, dof, expected = chi2_contingency(confusion_matrix, correction=False)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))


cat_cols = [col for col in df.columns if str(df[col].dtype) == 'category']

# Initialize an empty DataFrame for the association matrix
assoc_matrix = pd.DataFrame(np.ones((len(cat_cols), len(cat_cols))),
                            index=cat_cols, columns=cat_cols)

for col1 in cat_cols:
    for col2 in cat_cols:
        if col1 == col2:
            assoc_matrix.loc[col1, col2] = 1.0
        else:
            assoc_matrix.loc[col1, col2] = cramers_v(df[col1], df[col2])

# %%
plt.figure(figsize=(12,10))
sns.heatmap(assoc_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True,
            cbar_kws={'label': "Cramér's V (Association Strength)"})
plt.title("Association Heatmap (Cramér's V) for Categorical Features")
plt.tight_layout()
plt.show()

# %%
# 1. Country vs. self_employed
ctab1 = pd.crosstab(df['Country'], df['self_employed'])
print("\nCountry vs. self_employed:\n", ctab1)
ctab1.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. self_employed')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 2. Occupation vs. self_employed
ctab2 = pd.crosstab(df['Occupation'], df['self_employed'])
print("\nOccupation vs. self_employed:\n", ctab2)
ctab2.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Occupation vs. self_employed')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# 3. Country vs. Gender (optional)
ctab3 = pd.crosstab(df['Country'], df['Gender'])
print("\nCountry vs. Gender:\n", ctab3)
ctab3.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. Gender')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# 4. Country vs. family_history (optional)
ctab4 = pd.crosstab(df['Country'], df['family_history'])
print("\nCountry vs. family_history:\n", ctab4)
ctab4.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Country vs. family_history')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Country vs. self_employed:
#  self_employed               No   Yes
# Country
# Australia                 5234   780
# Belgium                    821     0
# Bosnia and Herzegovina     390     0
# Brazil                    1560   780
# Canada                   14676  2853
# Colombia                   390     0
# Costa Rica                 390     0
# Croatia                      0   390
# Czech Republic             390     0
# Denmark                      0   780
# Finland                    390     0
# France                    1950   390
# Georgia                    390     0
# Germany                   3510  1170
# Greece                     780     0
# India                     2381   390
# Ireland                   3592  1950
# Israel                    1560     0
# Italy                     1560     0
# Mexico                       0   390
# Moldova                    390     0
# Netherlands               4721  1170
# New Zealand               1991     0
# Nigeria                    390     0
# Philippines                390     0
# Poland                     431   390
# Portugal                   390     0
# Russia                     780     0
# Singapore                  780     0
# South Africa              1560   431
# Sweden                    2812     0
# Switzerland               1170   390
# Thailand                     0   390
# United Kingdom           43515  7061
# United States           156427  9442
# Occupation vs. self_employed:
#  self_employed     No   Yes
# Occupation
# Business       43947  4975
# Corporate      53408  6206
# Housewife      58093  6635
# Others         46212  5218
# Student        54051  6113
# Country vs. Gender:
#  Gender                  Female    Male
# Country
# Australia                 1724    4290
# Belgium                    431     390
# Bosnia and Herzegovina       0     390
# Brazil                       0    2340
# Canada                    3879   13650
# Colombia                     0     390
# Costa Rica                   0     390
# Croatia                      0     390
# Czech Republic               0     390
# Denmark                      0     780
# Finland                      0     390
# France                       0    2340
# Georgia                      0     390
# Germany                      0    4680
# Greece                       0     780
# India                      431    2340
# Ireland                    862    4680
# Israel                       0    1560
# Italy                        0    1560
# Mexico                       0     390
# Moldova                      0     390
# Netherlands                431    5460
# New Zealand                431    1560
# Nigeria                      0     390
# Philippines                  0     390
# Poland                     431     390
# Portugal                     0     390
# Russia                       0     780
# Singapore                    0     780
# South Africa               431    1560
# Sweden                     862    1950
# Switzerland                  0    1560
# Thailand                     0     390
# United Kingdom            6896   43680
# United States            34049  131820
# Country vs. family_history:
#  family_history             No    Yes
# Country
# Australia                3120   2894
# Belgium                   821      0
# Bosnia and Herzegovina      0    390
# Brazil                   1560    780
# Canada                   9832   7697
# Colombia                  390      0
# Costa Rica                390      0
# Croatia                   390      0
# Czech Republic              0    390
# Denmark                     0    780
# Finland                   390      0
# France                   1560    780
# Georgia                   390      0
# Germany                  3120   1560
# Greece                    780      0
# India                    2340    431
# Ireland                  3161   2381
# Israel                   1560      0
# Italy                    1560      0
# Mexico                    390      0
# Moldova                   390      0
# Netherlands              3551   2340
# New Zealand              1170    821
# Nigeria                   390      0
# Philippines               390      0
# Poland                    821      0
# Portugal                  390      0
# Russia                    780      0
# Singapore                 780      0
# South Africa              780   1211
# Sweden                   1950    862
# Switzerland               390   1170
# Thailand                  390      0
# United Kingdom          35818  14758
# United States           92613  73256

# %% [markdown]
# The dataset is heavily dominated by the United States and United Kingdom, with the U.S. showing a balanced family history split and the U.K. slightly skewed toward those without it. Meanwhile, over 20 countries contribute only 390 responses each, often entirely male, highlighting artificial sampling, gender imbalance, and low statistical utility, which can compromise fairness, generalizability, and model robustness in global mental health predictions.

# %% [markdown]
# **Filter out countries with small or gender-skewed sample sizes to reduce bias**

# %%
# Get countries with ≥1,000 total responses
country_counts = df['Country'].value_counts()
top_countries = country_counts[country_counts >= 1000].index

# Get countries with ≥200 female and male respondents
gender_counts = df.groupby(['Country', 'Gender'], observed=False).size().unstack(fill_value=0)
balanced_countries = gender_counts[(gender_counts['Female'] >= 200) & (gender_counts['Male'] >= 200)].index

# Intersect both criteria
best_countries = sorted(set(top_countries) & set(balanced_countries))

# Filter the original DataFrame
df_filtered = df[df['Country'].isin(best_countries)].copy()

# Summary
print("\nOriginal shape:", df.shape)
print("Filtered shape:", df_filtered.shape)
print("\nFinal Selected Countries:")
for country in best_countries:
    print("-", country)
print(f"\nTotal Selected Countries: {len(best_countries)}")
# Out:
# Original shape: (284858, 17)
# Filtered shape: (260986, 17)
#
# Final Selected Countries:
# - Australia
# - Canada
# - India
# - Ireland
# - Netherlands
# - New Zealand
# - South Africa
# - Sweden
# - United Kingdom
# - United States
#
# Total Selected Countries: 10

# %% [markdown]
# ### Defining Risk

# %%
# !pip install kmodes --quiet
from kmodes.kmodes import KModes

# %%
df_filtered.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
# Define your filtered dataset and categorical features
cat_features = [
    'Gender', 'Country', 'Occupation', 'self_employed', 'family_history',
    'treatment', 'Days_Indoors', 'Growing_Stress', 'Changes_Habits',
    'Mental_Health_History', 'Mood_Swings', 'Coping_Struggles',
    'Work_Interest', 'Social_Weakness', 'mental_health_interview', 'care_options'
]

X = df_filtered[cat_features].astype(str)
km = KModes(n_clusters=3, init='Huang', n_init=5, verbose=1, random_state=42)
clusters = km.fit_predict(X)
df_filtered['risk_cluster'] = clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 73310, cost: 1813191.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 31906, cost: 1817808.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 66214, cost: 1799281.0
# Run 3, iteration: 2/100, moves: 22402, cost: 1799281.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 39321, cost: 1826005.0
# Run 4, iteration: 2/100, moves: 35452, cost: 1805630.0
# Run 4, iteration: 3/100, moves: 16414, cost: 1805630.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 66049, cost: 1804320.0
# Best run was number 3

# %%
# Cluster Centroid Profiles: Most Common Feature Values per Risk Group
cluster_modes = pd.DataFrame(km.cluster_centroids_, columns=cat_features)
cluster_modes
# Out:
#   Gender        Country Occupation self_employed family_history treatment  \
# 0   Male  United States    Student            No             No        No
# 1   Male  United States     Others            No            Yes       Yes
# 2   Male  United States  Corporate            No             No       Yes
#
#   Days_Indoors Growing_Stress Changes_Habits Mental_Health_History  \
# 0    1-14 days          Maybe            Yes                 Maybe
# 1   31-60 days          Maybe            Yes                    No
# 2    1-14 days            Yes             No                   Yes
#
#   Mood_Swings Coping_Struggles Work_Interest Social_Weakness  \
# 0        High              Yes            No              No
# 1      Medium               No         Maybe             Yes
# 2         Low               No         Maybe           Maybe
#
#   mental_health_interview care_options
# 0                      No           No
# 1                      No          Yes
# 2                      No          Yes

# %%
# Interpret cluster composition
for i in range(3):
    print(f"\n--- Cluster {i} ---")
    display(df_filtered[df_filtered['risk_cluster'] == i].mode().iloc[0])
# Out:
# --- Cluster 0 ---
# Timestamp                  2014-08-27 12:31:00
# Gender                                    Male
# Country                          United States
# Occupation                             Student
# self_employed                               No
# family_history                              No
# treatment                                   No
# Days_Indoors                         1-14 days
# Growing_Stress                           Maybe
# Changes_Habits                             Yes
# Mental_Health_History                    Maybe
# Mood_Swings                               High
# Coping_Struggles                           Yes
# Work_Interest                               No
# Social_Weakness                             No
# mental_health_interview                     No
# care_options                                No
# risk_cluster                                 0
# Name: 0, dtype: object
# --- Cluster 1 ---
# Timestamp                  2014-08-27 12:53:00
# Gender                                    Male
# Country                          United States
# Occupation                              Others
# self_employed                               No
# family_history                             Yes
# treatment                                  Yes
# Days_Indoors                        31-60 days
# Growing_Stress                           Maybe
# Changes_Habits                             Yes
# Mental_Health_History                       No
# Mood_Swings                             Medium
# Coping_Struggles                            No
# Work_Interest                            Maybe
# Social_Weakness                            Yes
# mental_health_interview                     No
# care_options                               Yes
# risk_cluster                                 1
# Name: 0, dtype: object
# --- Cluster 2 ---
# Timestamp                  2014-08-27 12:31:00
# Gender                                    Male
# Country                          United States
# Occupation                           Corporate
# self_employed                               No
# family_history                              No
# treatment                                  Yes
# Days_Indoors                         1-14 days
# Growing_Stress                             Yes
# Changes_Habits                              No
# Mental_Health_History                      Yes
# Mood_Swings                                Low
# Coping_Struggles                            No
# Work_Interest                            Maybe
# Social_Weakness                          Maybe
# mental_health_interview                     No
# care_options                               Yes
# risk_cluster                                 2
# Name: 0, dtype: object

# %% [markdown]
# #### Cluster 1 — Low Risk
# This cluster contains individuals who show minimal evidence of current or past mental health challenges. They generally have no family history, have not sought treatment, and do not report significant struggles or mood swings.
#
# #### Cluster 0 — Medium Risk
# Individuals in this cluster have some evidence of mental health risk—such as family history or a past episode—but do not show as many simultaneous warning signs as those in the high-risk cluster. Their answers suggest a moderate level of concern.
#
# #### Cluster 2 — High Risk
# This group is at the greatest risk for mental health issues, as they frequently report past treatment, high stress, difficulties coping, and/or intense mood swings. The clustering of several risk factors points to a high-risk profile.

# %%
print(df_filtered['risk_cluster'].value_counts())
# Out:
# risk_cluster
# 0    119410
# 1     78567
# 2     63009
# Name: count, dtype: int64

# %%
# Assign interpretable labels
risk_labels = {
    0: 'Medium',   # Largest cluster
    1: 'Low',      # Middle-sized cluster
    2: 'High'      # Smallest cluster, likely highest risk
}

df_filtered['risk_label'] = df_filtered['risk_cluster'].map(risk_labels)

# %%
# Sample of Raw Records for Manual Inspection
pd.set_option('display.max_rows', 100)  # Show up to 100 rows in the output
df_filtered.sample(n=100, random_state=42)  # 100 random rows, same each time with the seed
# Out:
#                  Timestamp  Gender         Country Occupation self_employed  \
# 39629  2014-08-28 02:32:00  Female  United Kingdom  Housewife            No
# 242398 2014-08-28 22:22:00    Male   United States    Student            No
# 234382 2014-08-28 17:57:00    Male  United Kingdom  Corporate            No
# 9716   2014-08-27 15:34:00  Female   United States   Business            No
# 278528 2014-08-28 00:43:00    Male   United States     Others            No
# 221204 2014-08-27 14:45:00    Male   United States  Housewife            No
# 93748  2014-08-27 11:45:00    Male   United States     Others            No
# 104911 2014-08-27 13:27:00    Male          Canada     Others            No
# 157837 2014-08-27 14:23:00    Male   United States    Student            No
# 23643  2014-08-27 17:32:00  Female   United States  Corporate            No
# 283551 2014-08-28 15:50:00    Male          Sweden  Housewife            No
# 44294  2014-08-27 12:18:00  Female   United States     Others            No
# 12806  2014-08-29 11:54:00  Female   United States   Business            No
# 273450 2014-08-27 14:11:00    Male   United States  Corporate            No
# 258050 2014-08-27 13:34:00    Male   United States    Student            No
# 169303 2014-08-30 20:19:00    Male   United States  Housewife            No
# 87096  2014-08-27 13:55:00    Male   United States   Business            No
# 140333 2014-08-29 08:57:00    Male  United Kingdom   Business            No
# 1329   2015-02-24 08:54:00  Female  United Kingdom    Student            No
# 101189 2014-08-27 12:43:00    Male  United Kingdom  Corporate            No
# 221953 2014-08-28 03:13:00    Male   United States  Housewife           Yes
# 1251   2014-08-27 16:19:00  Female  United Kingdom    Student            No
# 256215 2014-08-27 13:49:00    Male       Australia     Others            No
# 42477  2014-08-27 11:51:00  Female       Australia     Others            No
# 78924  2014-09-23 20:05:00    Male   United States    Student            No
# 260098 2014-08-28 08:06:00    Male          Canada  Housewife            No
# 39539  2014-08-29 09:51:00  Female   United States   Business            No
# 21021  2014-08-29 05:57:00  Female  United Kingdom  Housewife           Yes
# 78510  2014-08-27 14:28:00    Male   United States    Student            No
# 227388 2014-08-27 15:35:00    Male   United States   Business            No
# 77901  2014-08-27 14:34:00    Male   United States  Corporate            No
# 74451  2014-08-28 15:50:00    Male          Sweden  Housewife            No
# 229476 2014-08-28 21:22:00    Male   United States  Housewife            No
# 38482  2014-08-27 11:43:00  Female   United States     Others            No
# 3233   2014-08-28 21:41:00  Female   United States  Housewife            No
# 138912 2014-08-27 23:09:00    Male   United States   Business            No
# 48653  2014-08-27 12:40:00  Female   United States  Housewife            No
# 286369 2014-08-27 14:18:00    Male   United States    Student            No
# 67731  2014-08-28 21:22:00    Male   United States     Others            No
# 40610  2014-08-28 12:12:00  Female  United Kingdom  Housewife            No
# 199328 2014-08-28 17:59:00    Male  United Kingdom  Corporate           Yes
# 238030 2014-08-28 14:00:00    Male   United States  Corporate            No
# 109473 2014-08-28 11:48:00    Male     Netherlands  Corporate           Yes
# 135949 2014-08-28 15:43:00    Male   United States   Business            No
# 257229 2014-08-29 16:07:00    Male     Netherlands    Student            No
# 230414 2014-08-27 14:28:00    Male   United States  Housewife            No
# 78913  2014-09-02 17:04:00    Male     Netherlands    Student           Yes
# 59940  2014-08-27 12:05:00    Male   United States   Business            No
# 78436  2014-08-27 12:48:00    Male  United Kingdom    Student            No
# 971    2014-08-27 11:37:00  Female   United States    Student            No
# 206506 2014-08-27 16:21:00    Male   United States  Housewife           Yes
# 118751 2014-08-28 17:22:00    Male   United States  Corporate            No
# 55614  2014-08-27 11:43:00    Male   United States     Others            No
# 5976   2014-08-27 17:08:00  Female   United States   Business            No
# 34570  2014-08-28 18:21:00  Female  United Kingdom  Corporate            No
# 66507  2014-08-28 22:20:00    Male  United Kingdom    Student           Yes
# 233972 2014-08-27 11:50:00    Male  United Kingdom  Corporate            No
# 259235 2014-08-27 12:39:00    Male   United States  Housewife            No
# 35814  2015-02-24 08:54:00  Female  United Kingdom  Housewife            No
# 172686 2014-08-27 16:28:00    Male  United Kingdom     Others            No
# 54484  2014-08-27 13:33:00    Male    South Africa     Others            No
# 209147 2014-08-28 17:02:00    Male   United States  Housewife            No
# 32192  2014-08-27 11:51:00  Female       Australia  Corporate            No
# 281891 2015-02-21 10:00:00    Male   United States     Others            No
# 244892 2014-08-29 09:23:00    Male  United Kingdom   Business            No
# 197278 2014-08-27 16:15:00    Male   United States  Housewife            No
# 1237   2014-08-27 14:13:00  Female   United States    Student            No
# 253292 2014-08-27 22:04:00    Male   United States    Student            No
# 10383  2014-08-29 11:23:00  Female          Canada  Housewife            No
# 75108  2014-08-28 19:35:00    Male   United States   Business            No
# 25817  2014-08-27 16:27:00  Female   United States    Student            No
# 183626 2014-08-27 13:22:00    Male   United States    Student            No
# 144218 2014-08-27 12:33:00    Male          Canada    Student            No
# 161289 2014-08-29 16:07:00    Male     Netherlands  Corporate            No
# 111292 2014-08-28 10:18:00    Male   United States  Housewife            No
# 140318 2014-08-29 00:43:00    Male   United States   Business            No
# 273867 2014-09-02 09:57:00    Male   United States  Corporate            No
# 119295 2014-08-28 10:35:00    Male   United States    Student            No
# 51232  2014-08-27 17:37:00  Female          Canada  Housewife           Yes
# 232605 2014-08-29 10:38:00    Male   United States  Corporate            No
# 170139 2014-08-27 14:25:00    Male   United States  Housewife           Yes
# 279494 2014-08-27 12:05:00    Male   United States    Student            No
# 202882 2014-08-28 00:17:00    Male   United States   Business            No
# 202545 2015-02-21 04:55:00    Male       Australia    Student            No
# 1954   2014-08-27 12:55:00  Female   United States     Others            No
# 171447 2014-08-27 16:14:00    Male   United States  Housewife            No
# 23048  2014-08-27 22:14:00  Female   United States   Business            No
# 220504 2014-08-27 12:50:00    Male  United Kingdom     Others            No
# 52661  2014-08-27 14:03:00    Male   United States     Others            No
# 288994 2014-08-28 04:09:00    Male  United Kingdom    Student            No
# 248306 2014-08-27 15:43:00    Male   United States     Others            No
# 252664 2014-08-27 19:41:00    Male   United States     Others            No
# 63497  2014-08-29 12:45:00    Male   United States  Housewife            No
# 128    2014-08-27 11:52:00  Female   United States    Student            No
# 137042 2014-08-27 19:34:00    Male          Canada  Housewife            No
# 164743 2014-08-27 23:10:00    Male   United States  Housewife            No
# 217857 2014-08-29 11:43:00    Male   United States   Business            No
# 143433 2014-08-29 11:12:00    Male   United States    Student            No
# 199971 2014-08-29 00:11:00    Male   United States  Corporate            No
# 44116  2014-08-28 11:47:00  Female   United States  Corporate            No
#
#        family_history treatment        Days_Indoors Growing_Stress  \
# 39629              No       Yes          15-30 days             No
# 242398             No       Yes    Go out Every day          Maybe
# 234382            Yes       Yes          31-60 days            Yes
# 9716               No       Yes          15-30 days            Yes
# 278528            Yes       Yes          31-60 days             No
# 221204            Yes       Yes  More than 2 months             No
# 93748              No        No          31-60 days          Maybe
# 104911            Yes       Yes           1-14 days          Maybe
# 157837             No        No  More than 2 months            Yes
# 23643             Yes       Yes          31-60 days          Maybe
# 283551             No       Yes    Go out Every day             No
# 44294              No        No    Go out Every day            Yes
# 12806              No       Yes          15-30 days            Yes
# 273450             No        No  More than 2 months          Maybe
# 258050             No        No           1-14 days             No
# 169303             No        No          15-30 days          Maybe
# 87096              No        No          15-30 days            Yes
# 140333            Yes       Yes           1-14 days            Yes
# 1329              Yes       Yes           1-14 days            Yes
# 101189             No       Yes  More than 2 months            Yes
# 221953             No        No           1-14 days            Yes
# 1251              Yes       Yes           1-14 days            Yes
# 256215            Yes       Yes           1-14 days          Maybe
# 42477             Yes       Yes           1-14 days            Yes
# 78924              No        No    Go out Every day            Yes
# 260098            Yes        No           1-14 days             No
# 39539             Yes        No  More than 2 months             No
# 21021             Yes       Yes    Go out Every day             No
# 78510              No        No    Go out Every day            Yes
# 227388            Yes       Yes           1-14 days            Yes
# 77901              No        No    Go out Every day          Maybe
# 74451              No       Yes    Go out Every day             No
# 229476            Yes        No           1-14 days             No
# 38482             Yes       Yes          15-30 days          Maybe
# 3233              Yes       Yes          31-60 days            Yes
# 138912             No        No          15-30 days            Yes
# 48653              No        No    Go out Every day             No
# 286369            Yes       Yes    Go out Every day          Maybe
# 67731             Yes        No           1-14 days             No
# 40610              No        No           1-14 days          Maybe
# 199328             No        No          15-30 days             No
# 238030            Yes        No  More than 2 months             No
# 109473             No        No           1-14 days            Yes
# 135949            Yes       Yes           1-14 days          Maybe
# 257229            Yes       Yes  More than 2 months             No
# 230414             No       Yes  More than 2 months          Maybe
# 78913              No        No    Go out Every day            Yes
# 59940              No        No  More than 2 months            Yes
# 78436              No        No    Go out Every day            Yes
# 971               Yes       Yes           1-14 days            Yes
# 206506            Yes       Yes           1-14 days             No
# 118751             No        No    Go out Every day            Yes
# 55614              No       Yes          31-60 days             No
# 5976              Yes       Yes          15-30 days          Maybe
# 34570             Yes       Yes          31-60 days          Maybe
# 66507             Yes       Yes    Go out Every day          Maybe
# 233972             No        No          31-60 days            Yes
# 259235             No        No          15-30 days            Yes
# 35814             Yes       Yes          15-30 days          Maybe
# 172686             No       Yes          31-60 days          Maybe
# 54484              No        No    Go out Every day            Yes
# 209147             No        No           1-14 days          Maybe
# 32192             Yes       Yes          15-30 days            Yes
# 281891            Yes       Yes    Go out Every day            Yes
# 244892             No        No          31-60 days             No
# 197278             No       Yes          15-30 days             No
# 1237              Yes       Yes           1-14 days            Yes
# 253292            Yes       Yes    Go out Every day          Maybe
# 10383             Yes       Yes    Go out Every day            Yes
# 75108             Yes        No          31-60 days            Yes
# 25817             Yes       Yes    Go out Every day            Yes
# 183626             No       Yes    Go out Every day          Maybe
# 144218             No       Yes  More than 2 months             No
# 161289            Yes       Yes          31-60 days             No
# 111292            Yes       Yes    Go out Every day          Maybe
# 140318            Yes       Yes           1-14 days            Yes
# 273867            Yes       Yes  More than 2 months          Maybe
# 119295             No        No  More than 2 months            Yes
# 51232             Yes       Yes    Go out Every day            Yes
# 232605            Yes       Yes          31-60 days            Yes
# 170139             No       Yes    Go out Every day            Yes
# 279494            Yes        No          31-60 days            Yes
# 202882             No        No           1-14 days             No
# 202545             No       Yes           1-14 days          Maybe
# 1954               No        No           1-14 days            Yes
# 171447             No        No    Go out Every day             No
# 23048             Yes       Yes    Go out Every day            Yes
# 220504             No        No  More than 2 months          Maybe
# 52661             Yes        No          31-60 days            Yes
# 288994            Yes       Yes  More than 2 months            Yes
# 248306             No        No          15-30 days          Maybe
# 252664             No       Yes          31-60 days             No
# 63497              No        No          15-30 days            Yes
# 128                No        No    Go out Every day             No
# 137042             No        No           1-14 days            Yes
# 164743             No        No          31-60 days            Yes
# 217857             No        No           1-14 days          Maybe
# 143433             No        No          15-30 days          Maybe
# 199971             No       Yes           1-14 days            Yes
# 44116              No       Yes          15-30 days            Yes
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# 39629             Yes                    No      Medium               No
# 242398             No                 Maybe         Low              Yes
# 234382          Maybe                   Yes      Medium              Yes
# 9716            Maybe                 Maybe        High               No
# 278528             No                    No         Low              Yes
# 221204             No                 Maybe        High              Yes
# 93748           Maybe                 Maybe        High               No
# 104911          Maybe                   Yes      Medium              Yes
# 157837            Yes                   Yes        High              Yes
# 23643              No                 Maybe      Medium              Yes
# 283551             No                   Yes      Medium               No
# 44294             Yes                 Maybe      Medium              Yes
# 12806              No                    No      Medium              Yes
# 273450            Yes                    No         Low               No
# 258050            Yes                    No        High              Yes
# 169303          Maybe                 Maybe         Low               No
# 87096             Yes                   Yes        High              Yes
# 140333          Maybe                    No      Medium              Yes
# 1329              Yes                    No        High               No
# 101189          Maybe                   Yes      Medium               No
# 221953             No                 Maybe         Low               No
# 1251              Yes                    No        High               No
# 256215          Maybe                   Yes      Medium               No
# 42477           Maybe                    No      Medium              Yes
# 78924             Yes                    No        High              Yes
# 260098            Yes                    No        High              Yes
# 39539             Yes                   Yes         Low              Yes
# 21021              No                    No        High               No
# 78510             Yes                    No        High              Yes
# 227388          Maybe                   Yes        High               No
# 77901           Maybe                   Yes        High               No
# 74451           Maybe                   Yes        High               No
# 229476          Maybe                   Yes      Medium               No
# 38482              No                   Yes         Low               No
# 3233               No                 Maybe      Medium               No
# 138912          Maybe                   Yes      Medium               No
# 48653           Maybe                    No      Medium               No
# 286369          Maybe                    No        High               No
# 67731              No                   Yes         Low               No
# 40610             Yes                   Yes      Medium               No
# 199328             No                    No      Medium               No
# 238030             No                   Yes        High               No
# 109473          Maybe                 Maybe         Low              Yes
# 135949          Maybe                    No        High               No
# 257229          Maybe                   Yes         Low              Yes
# 230414            Yes                   Yes        High              Yes
# 78913             Yes                    No        High              Yes
# 59940              No                 Maybe      Medium               No
# 78436             Yes                    No        High              Yes
# 971             Maybe                    No      Medium               No
# 206506            Yes                    No      Medium               No
# 118751             No                   Yes      Medium               No
# 55614              No                 Maybe         Low               No
# 5976              Yes                    No        High              Yes
# 34570           Maybe                   Yes      Medium              Yes
# 66507              No                 Maybe        High              Yes
# 233972          Maybe                   Yes      Medium              Yes
# 259235            Yes                   Yes         Low              Yes
# 35814             Yes                   Yes        High               No
# 172686          Maybe                 Maybe      Medium               No
# 54484             Yes                    No      Medium              Yes
# 209147            Yes                 Maybe         Low               No
# 32192           Maybe                    No        High               No
# 281891            Yes                    No      Medium              Yes
# 244892             No                    No         Low              Yes
# 197278             No                    No         Low               No
# 1237              Yes                    No        High               No
# 253292          Maybe                   Yes        High               No
# 10383           Maybe                   Yes      Medium               No
# 75108           Maybe                    No      Medium              Yes
# 25817              No                    No        High               No
# 183626             No                   Yes        High              Yes
# 144218             No                    No         Low              Yes
# 161289             No                    No      Medium              Yes
# 111292             No                   Yes        High               No
# 140318          Maybe                    No      Medium              Yes
# 273867            Yes                    No         Low               No
# 119295            Yes                   Yes         Low              Yes
# 51232              No                    No         Low               No
# 232605          Maybe                 Maybe      Medium               No
# 170139            Yes                    No         Low              Yes
# 279494          Maybe                 Maybe         Low               No
# 202882          Maybe                   Yes         Low               No
# 202545            Yes                    No      Medium               No
# 1954            Maybe                 Maybe        High              Yes
# 171447            Yes                    No        High               No
# 23048              No                 Maybe        High               No
# 220504          Maybe                 Maybe        High              Yes
# 52661           Maybe                    No        High               No
# 288994          Maybe                    No      Medium              Yes
# 248306             No                   Yes        High               No
# 252664            Yes                    No      Medium              Yes
# 63497           Maybe                    No      Medium               No
# 128               Yes                    No      Medium              Yes
# 137042          Maybe                    No         Low               No
# 164743          Maybe                 Maybe      Medium              Yes
# 217857            Yes                    No      Medium               No
# 143433          Maybe                   Yes         Low               No
# 199971             No                    No      Medium               No
# 44116              No                    No      Medium              Yes
#
#        Work_Interest Social_Weakness mental_health_interview care_options  \
# 39629             No             Yes                      No           No
# 242398            No             Yes                      No           No
# 234382         Maybe              No                      No           No
# 9716              No              No                      No          Yes
# 278528         Maybe           Maybe                      No          Yes
# 221204            No              No                   Maybe           No
# 93748             No           Maybe                      No     Not sure
# 104911           Yes           Maybe                      No          Yes
# 157837           Yes           Maybe                      No     Not sure
# 23643          Maybe              No                      No          Yes
# 283551            No           Maybe                      No          Yes
# 44294            Yes             Yes                      No     Not sure
# 12806             No             Yes                   Maybe           No
# 273450           Yes           Maybe                      No     Not sure
# 258050         Maybe           Maybe                   Maybe          Yes
# 169303         Maybe           Maybe                      No     Not sure
# 87096            Yes              No                      No           No
# 140333            No             Yes                      No           No
# 1329             Yes           Maybe                   Maybe          Yes
# 101189            No           Maybe                      No          Yes
# 221953            No              No                      No     Not sure
# 1251             Yes           Maybe                   Maybe     Not sure
# 256215            No           Maybe                      No          Yes
# 42477            Yes              No                      No     Not sure
# 78924            Yes           Maybe                      No           No
# 260098           Yes           Maybe                      No           No
# 39539            Yes           Maybe                      No          Yes
# 21021          Maybe             Yes                      No           No
# 78510            Yes           Maybe                   Maybe     Not sure
# 227388           Yes             Yes                      No          Yes
# 77901          Maybe             Yes                      No           No
# 74451            Yes              No                      No          Yes
# 229476         Maybe             Yes                     Yes           No
# 38482             No           Maybe                      No          Yes
# 3233             Yes              No                      No     Not sure
# 138912         Maybe             Yes                      No          Yes
# 48653          Maybe           Maybe                      No     Not sure
# 286369           Yes              No                      No           No
# 67731             No              No                     Yes           No
# 40610             No             Yes                   Maybe           No
# 199328         Maybe           Maybe                      No          Yes
# 238030           Yes             Yes                      No          Yes
# 109473           Yes           Maybe                   Maybe           No
# 135949            No           Maybe                      No          Yes
# 257229           Yes           Maybe                   Maybe     Not sure
# 230414            No              No                      No           No
# 78913            Yes           Maybe                      No     Not sure
# 59940          Maybe             Yes                   Maybe     Not sure
# 78436            Yes           Maybe                      No     Not sure
# 971               No              No                   Maybe          Yes
# 206506         Maybe              No                      No          Yes
# 118751            No           Maybe                      No           No
# 55614          Maybe             Yes                      No           No
# 5976             Yes             Yes                      No          Yes
# 34570            Yes              No                      No           No
# 66507            Yes           Maybe                      No           No
# 233972         Maybe              No                   Maybe     Not sure
# 259235           Yes              No                      No           No
# 35814            Yes           Maybe                   Maybe          Yes
# 172686            No              No                   Maybe          Yes
# 54484          Maybe           Maybe                      No           No
# 209147           Yes              No                      No           No
# 32192          Maybe              No                      No     Not sure
# 281891            No           Maybe                      No           No
# 244892            No              No                      No           No
# 197278            No              No                      No     Not sure
# 1237             Yes           Maybe                      No          Yes
# 253292         Maybe           Maybe                      No          Yes
# 10383            Yes           Maybe                      No     Not sure
# 75108          Maybe           Maybe                      No     Not sure
# 25817             No              No                      No     Not sure
# 183626           Yes           Maybe                      No           No
# 144218           Yes              No                      No     Not sure
# 161289         Maybe             Yes                   Maybe     Not sure
# 111292            No           Maybe                   Maybe          Yes
# 140318            No             Yes                      No          Yes
# 273867           Yes           Maybe                      No     Not sure
# 119295         Maybe              No                      No     Not sure
# 51232             No             Yes                      No     Not sure
# 232605           Yes              No                   Maybe     Not sure
# 170139            No              No                      No          Yes
# 279494           Yes             Yes                      No           No
# 202882            No             Yes                   Maybe           No
# 202545            No           Maybe                      No          Yes
# 1954              No             Yes                      No     Not sure
# 171447         Maybe             Yes                      No           No
# 23048             No              No                      No     Not sure
# 220504            No           Maybe                   Maybe     Not sure
# 52661             No             Yes                      No           No
# 288994         Maybe           Maybe                      No     Not sure
# 248306           Yes           Maybe                      No           No
# 252664         Maybe              No                   Maybe           No
# 63497          Maybe             Yes                      No          Yes
# 128            Maybe              No                      No           No
# 137042         Maybe              No                      No           No
# 164743           Yes           Maybe                      No           No
# 217857            No             Yes                   Maybe           No
# 143433            No             Yes                      No           No
# 199971            No              No                   Maybe          Yes
# 44116             No           Maybe                      No     Not sure
#
#         risk_cluster risk_label
# 39629              1        Low
# 242398             0     Medium
# 234382             1        Low
# 9716               0     Medium
# 278528             1        Low
# 221204             0     Medium
# 93748              0     Medium
# 104911             1        Low
# 157837             0     Medium
# 23643              1        Low
# 283551             2       High
# 44294              0     Medium
# 12806              0     Medium
# 273450             2       High
# 258050             0     Medium
# 169303             2       High
# 87096              0     Medium
# 140333             1        Low
# 1329               1        Low
# 101189             2       High
# 221953             0     Medium
# 1251               1        Low
# 256215             1        Low
# 42477              1        Low
# 78924              0     Medium
# 260098             0     Medium
# 39539              2       High
# 21021              1        Low
# 78510              0     Medium
# 227388             2       High
# 77901              0     Medium
# 74451              2       High
# 229476             1        Low
# 38482              2       High
# 3233               1        Low
# 138912             2       High
# 48653              1        Low
# 286369             0     Medium
# 67731              0     Medium
# 40610              0     Medium
# 199328             2       High
# 238030             2       High
# 109473             0     Medium
# 135949             1        Low
# 257229             2       High
# 230414             0     Medium
# 78913              0     Medium
# 59940              2       High
# 78436              0     Medium
# 971                1        Low
# 206506             1        Low
# 118751             2       High
# 55614              1        Low
# 5976               1        Low
# 34570              1        Low
# 66507              0     Medium
# 233972             2       High
# 259235             0     Medium
# 35814              1        Low
# 172686             1        Low
# 54484              0     Medium
# 209147             0     Medium
# 32192              1        Low
# 281891             1        Low
# 244892             0     Medium
# 197278             2       High
# 1237               1        Low
# 253292             1        Low
# 10383              2       High
# 75108              1        Low
# 25817              0     Medium
# 183626             0     Medium
# 144218             0     Medium
# 161289             1        Low
# 111292             2       High
# 140318             1        Low
# 273867             1        Low
# 119295             0     Medium
# 51232              1        Low
# 232605             1        Low
# 170139             0     Medium
# 279494             0     Medium
# 202882             0     Medium
# 202545             1        Low
# 1954               0     Medium
# 171447             0     Medium
# 23048              0     Medium
# 220504             0     Medium
# 52661              1        Low
# 288994             1        Low
# 248306             0     Medium
# 252664             1        Low
# 63497              1        Low
# 128                0     Medium
# 137042             2       High
# 164743             0     Medium
# 217857             0     Medium
# 143433             0     Medium
# 199971             2       High
# 44116              2       High

# %%
pd.reset_option('display.max_rows')

# %%
sns.countplot(x='risk_label', data=df_filtered, order=["Low", "Medium", "High"])
plt.title("Distribution of Risk Labels")
plt.xlabel("Risk Level")
plt.ylabel("Number of Respondents")
plt.tight_layout()
plt.show()

# %% [markdown]
# The chart reveals a **moderate class imbalance** with the Medium-risk group being the largest, followed by Low- and then High-risk, suggesting potential need for class balancing techniques during modeling.

# %%
# Drop the cluster column to prevent contamination of inferential statistics
df_filtered.drop(columns=['risk_cluster'], inplace=True)  # Drop the cluster column
df_filtered['risk_label'] = df_filtered['risk_label'].astype('category')
df_filtered.head()
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
# 6 2014-08-27 11:51:00  Female      Australia  Corporate            No
# 7 2014-08-27 11:52:00  Female  United States  Corporate            No
# 8 2014-08-27 12:18:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
# 6            Yes       Yes    1-14 days            Yes             No
# 7             No        No    1-14 days            Yes             No
# 8             No        No    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 3                   Yes      Medium               No            No
# 4                   Yes      Medium               No            No
# 6                   Yes      Medium               No            No
# 7                   Yes      Medium               No            No
# 8                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options risk_label
# 3             Yes                   Maybe          Yes       High
# 4             Yes                      No          Yes       High
# 6             Yes                      No     Not sure       High
# 7             Yes                      No           No       High
# 8             Yes                      No     Not sure       High

# %%
from scipy.stats import chi2_contingency
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Chi-square for top features
X = df_filtered[cat_features].apply(LabelEncoder().fit_transform)
y = LabelEncoder().fit_transform(df_filtered['risk_label'])

chi_scores = chi2(X, y)
chi_df = pd.DataFrame({'Feature': cat_features, 'Chi2': chi_scores[0]})
chi_df.sort_values('Chi2', ascending=False)
# Out:
#                     Feature          Chi2
# 4            family_history  29852.383233
# 15             care_options  26633.053897
# 5                 treatment  25074.546324
# 7            Growing_Stress  14969.256182
# 10              Mood_Swings   9666.758733
# 11         Coping_Struggles   9495.722113
# 13          Social_Weakness   8751.265560
# 2                Occupation   7772.616848
# 9     Mental_Health_History   6620.166208
# 8            Changes_Habits   4918.670002
# 12            Work_Interest   3433.899780
# 6              Days_Indoors   1405.999736
# 0                    Gender    551.128430
# 3             self_employed    153.302369
# 14  mental_health_interview     66.914237
# 1                   Country     37.878610

# %%
# Plot top features
plt.figure(figsize=(10, 6))
sns.barplot(data=chi_df.head(10), x='Chi2', y='Feature')
plt.title("Top Features by Chi-Square Score")
plt.xlabel("Chi-Square Value")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Chi-Squared test was used post-clustering to assess feature association with mental health risk labels.
#
# **Top features** by Chi² score:
#
# * family_history, treatment, Growing_Stress, Mood_Swings, and care_options
#
#   *These variables reflect established psychological and social risk factors.*
#
# **Moderately associated features**:
#
# * Coping_Struggles, Social_Weakness, Occupation.
#
# **Low-impact features:**
#
# * Gender, Country, self_employed, mental_health_interview.
#
#   *These add minimal value and may introduce noise.*

# %%
# Filter out the too 3 countries to see if there are similiarities
top_countries = ['United States', 'United Kingdom', 'Canada']
country_groups = {country: df_filtered[df_filtered['Country'] == country] for country in top_countries}

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    return np.sqrt(phi2 / min(k - 1, r - 1))

categorical_cols = [
    'family_history', 'treatment', 'Coping_Struggles', 'Mood_Swings',
    'care_options', 'Social_Weakness', 'Changes_Habits',
    'Mental_Health_History', 'Work_Interest', 'Occupation',
    'Days_Indoors', 'self_employed', 'mental_health_interview'
]

top_features_by_country = {}

for country, group in country_groups.items():
    cramers_scores = {
        col: cramers_v(group[col], group['risk_label'])
        for col in categorical_cols if col in group.columns
    }
    sorted_scores = sorted(cramers_scores.items(), key=lambda item: item[1], reverse=True)
    top_features_by_country[country] = sorted_scores[:3]

for country, features in top_features_by_country.items():
    print(f"\nTop features for {country}:")
    for feature, score in features:
        print(f"  {feature}: {score:.3f}")
# Out:
# Top features for United States:
#   treatment: 0.448
#   family_history: 0.432
#   Coping_Struggles: 0.267
#
# Top features for United Kingdom:
#   treatment: 0.429
#   family_history: 0.414
#   Coping_Struggles: 0.267
#
# Top features for Canada:
#   family_history: 0.463
#   treatment: 0.435
#   care_options: 0.280

# %% [markdown]
# Across the United States, United Kingdom, and Canada, **treatment history** and **family history** consistently emerge as the strongest predictors of mental health risk, with Cramér’s V values ranging from 0.429 to 0.463. The third most influential feature varies by country:
#
# * Coping struggles in the U.S. and U.K.
#
# * Care options in Canada
#
# This variation highlights potential regional differences in how mental health risk is influenced. Overall, these patterns suggest that access to treatment, genetic predisposition, and the availability of support systems are universal drivers of mental health outcomes, while certain social or systemic factors may differ across nations.

# %% [markdown]
# **Cramer's V Heatmap (Filtered Data)**

# %%
# Define the Cramér’s V function
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2, _, _, _ = chi2_contingency(confusion_matrix, correction=False)
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k - 1)*(r - 1)) / (n - 1))
    rcorr = r - ((r - 1)**2) / (n - 1)
    kcorr = k - ((k - 1)**2) / (n - 1)
    return np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))

# Filter to categorical columns
cat_cols = [col for col in df_filtered.columns if df_filtered[col].dtype.name == 'category' or df_filtered[col].dtype == object]

# Include 'risk_label' if present
if 'risk_label' in df_filtered.columns:
    df_filtered['risk_label'] = df_filtered['risk_label'].astype('category')
    if 'risk_label' not in cat_cols:
        cat_cols.append('risk_label')

# Initialize empty matrix
assoc_matrix = pd.DataFrame(np.eye(len(cat_cols)), index=cat_cols, columns=cat_cols)

# Fill upper triangle of the matrix
for i, col1 in enumerate(cat_cols):
    for j, col2 in enumerate(cat_cols):
        if i < j:
            value = cramers_v(df_filtered[col1], df_filtered[col2])
            assoc_matrix.loc[col1, col2] = value
            assoc_matrix.loc[col2, col1] = value

# Convert all to float
assoc_matrix = assoc_matrix.astype(float)

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(
    assoc_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True,
    annot_kws={"size": 8}, cbar_kws={'label': "Cramér's V with risk labels (Association Strength)"}
)
plt.title("Categorical Association Heatmap (Cramér's V)")
plt.xticks(fontsize=10, rotation=45, ha='right')
plt.yticks(fontsize=10, rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# *The most actionable predictors of mental health risk are:*
# * Treatment status
# * Family history
# * Coping struggles
# * Access to care

# %% [markdown]
# ### Bivariate Visualization

# %%
# Select top countries
top_countries = ['United States', 'United Kingdom', 'Canada']
df_top = df_filtered[df_filtered['Country'].isin(top_countries)].copy()

# Remove unused categories from 'Country' if categorical
if str(df_top['Country'].dtype) == "category":
    df_top['Country'] = df_top['Country'].cat.remove_unused_categories()
else:
    # Optionally, force 'Country' to be categorical for nice plotting
    df_top['Country'] = pd.Categorical(df_top['Country'], categories=top_countries, ordered=False)

# Plot
g = sns.catplot(
    data=df_top,
    x='risk_label',
    hue='family_history',
    col='Country',
    kind='count',
    order=['Low', 'Medium', 'High'],
    col_wrap=3,
    height=4,
    aspect=1
)

# Add percentage labels
for ax in g.axes.flat:
    for c in ax.containers:
        heights = [b.get_height() for b in c]
        total = sum(heights)
        labels = [f'{(h / total * 100):.1f}%' if total > 0 else '' for h in heights]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Family History vs Risk Label by Country")
plt.show()

# %% [markdown]
# Across Canada, the United Kingdom, and the United States, individuals with a family history of mental illness consistently show lower proportions in the High-risk category compared to those without such history. Notably, in Canada and the U.S., those with family history are more concentrated in the Low-risk group, while in the U.K., they are predominantly in the Medium-risk category. This suggests that cultural or systemic factors may influence how family history correlates with perceived or reported mental health risk.

# %%
# Treatment vs Risk_Label by Coping_Struggles
g = sns.catplot(
    data=df_filtered,
    x='risk_label',
    hue='treatment',
    col='Coping_Struggles',
    kind='count',
    order=['Low', 'Medium', 'High'],
    height=4,
    aspect=1
)

for ax in g.axes.flat:
    for c in ax.containers:
        labels = [f'{(v.get_height() / sum([b.get_height() for b in c.patches])) * 100:.1f}%' if v.get_height() > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Treatment vs Risk Label by Coping Struggles")
plt.show()

# %% [markdown]
# Individuals with coping struggles who did not receive treatment showed an overwhelming concentration in the Medium risk group (83.2%), highlighting untreated vulnerability. In contrast, those who received treatment were more evenly distributed across risk levels, with only 38.2% remaining in the Medium category. This suggests that treatment significantly mitigates mental health risk among those struggling to cope.

# %%
# Mood_Swings vs Risk_Label by Gender
g = sns.catplot(
    data=df_filtered,
    x='risk_label',
    hue='Mood_Swings',
    col='Gender',
    kind='count',
    order=['Low', 'Medium', 'High'],
    height=4,
    aspect=1
)

for ax in g.axes.flat:
    for c in ax.containers:
        labels = [f'{(v.get_height() / sum([b.get_height() for b in c.patches])) * 100:.1f}%' if v.get_height() > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Mood Swings vs Risk Label by Gender (Proportions)")
plt.show()

# %% [markdown]
# High mood swings in males are strongly linked to Medium risk (67.5%), while females with medium mood swings tend to fall in the Low-risk group (54.4%), showing gender differences in how mood variability reflects mental health risk.

# %% [markdown]
# ### Trivariate Visualizations

# %%
# Occupation vs Risk Label by Gender
g = sns.catplot(
    data=df_filtered,
    kind='count',
    x='Occupation',
    hue='risk_label',
    col='Gender',
    height=5,
    aspect=1.2
)

for ax in g.axes.flat:
    for c in ax.containers:
        total = sum([b.get_height() for b in c])
        labels = [f'{(v.get_height() / total) * 100:.1f}%' if v.get_height() > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle('Occupation vs Risk Label by Gender')
g.set_xticklabels(rotation=45)
plt.show()

# %% [markdown]
# Among males, those in corporate roles show the highest Medium risk (40.4%), while male students have the highest proportion overall in that group (29.4%). In contrast, female risk distributions are more balanced across occupations, with no single group showing an extreme concentration.

# %%
# Select top countries
top_countries = ['United States', 'United Kingdom', 'Canada']
df_top = df_filtered[df_filtered['Country'].isin(top_countries)].copy()

# Remove unused categories from 'Country' if it's categorical
if str(df_top['Country'].dtype) == "category":
    df_top['Country'] = df_top['Country'].cat.remove_unused_categories()
else:
    df_top['Country'] = pd.Categorical(df_top['Country'], categories=top_countries, ordered=False)

# Plot
g = sns.catplot(
    data=df_top,
    x='risk_label',
    hue='treatment',
    col='Country',
    kind='count',
    order=['Low', 'Medium', 'High'],
    col_wrap=3,
    height=4,
    aspect=1
)

# Add percentage labels to each bar
for ax in g.axes.flat:
    for c in ax.containers:
        heights = [b.get_height() for b in c]
        total = sum(heights)
        labels = [f'{(h / total * 100):.1f}%' if total > 0 else '' for h in heights]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle("Treatment vs Risk Label by Country (Top 3)")
plt.show()

# %% [markdown]
# There is a clear **global treatment gap** across the United States, Canada, and the United Kingdom, as many individuals labeled as low risk have not received treatment, despite potentially experiencing symptoms. This indicates that treatment is not consistently aligned with actual need, either due to misclassification of risk or lack of access to care for those at higher risk.

# %%
# Care_Options vs Treatment by Risk_Label
g = sns.catplot(
    data=df_filtered,
    kind='count',
    x='treatment',
    hue='risk_label',
    col='care_options',
    height=5,
    aspect=1
)

for ax in g.axes.flat:
    for c in ax.containers:
        total = sum([b.get_height() for b in c.patches])
        labels = [f'{(v.get_height() / total) * 100:.1f}%' if v.get_height() > 0 else '' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge', fontsize=8)

g.fig.subplots_adjust(top=0.85)
g.fig.suptitle('Treatment vs Risk Label by Care Options')
g.set_xticklabels(rotation=45)
plt.show()

# %% [markdown]
# Individuals aware of available care options are significantly more likely to receive treatment.

# %%
# Save the cleaned and filtered dataset without target (for general use or EDA)
df_filtered.to_csv("aai-590-capstone-mental-health/data-assets/cleaned_mental_health_data.csv", index=False)
print("Cleaned data saved to '/aai-590-capstone-mental-health/data-assets/cleaned_mental_health_data.csv'")
# df_filtered.to_csv("./data-assets/cleaned_mental_health_data.csv", index=False)
# print("Cleaned data saved to '/data-assets/cleaned_mental_health_data.csv'")
# Out:
# Cleaned data saved to '/aai-590-capstone-mental-health/data-assets/cleaned_mental_health_data.csv'
